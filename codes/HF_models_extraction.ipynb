# %%
import time
import pandas as pd
import json

from huggingface_hub import HfApi
from huggingface_hub import hf_hub_url, get_hf_file_metadata
from huggingface_hub.utils import GatedRepoError

api = HfApi()


def find_model_size(repo_files, modelId):
    """
    Find the size of a model given its ID, considering only files of the highest priority extension present.

    Args:
        modelId: The ID of the model.

    Returns:
        The size of the model or None if not found.
    """
    api_token = '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'
    priority_extensions = ['.bin', '.safetensors', '.pth', '.h5', '.gguf', '.pt', '.ckpt', '.npz', '.model', '.onnx',
                           '.mgspack', '.pkl', '.whisper', '.nemo', '.joblib', '.pb', '.npy', '.cleanrl_model',
                           '.data-00000-of-00001', '.weights', '.ptl', '.binary', 'CNN_model', '.msgpack', '.addon',
                           '.mdl', '.tgt', '.src', '.tar', '.zip', '.tar.xz']
    # Filter files by allowed extensions
    model_files = [file for file in repo_files if any(file.endswith(ext) for ext in priority_extensions)]
    if not model_files:
        print(f"No model files found for {modelId}")
        return None

    for ext in priority_extensions:
        files_with_ext = [file for file in model_files if file.endswith(ext)]
        if files_with_ext:
            try:
                # Sum the sizes of all files with this extension
                file_size = sum(get_hf_file_metadata(hf_hub_url(repo_id=modelId, filename=model_file), token=api_token).size for model_file in files_with_ext)
                return file_size
            except GatedRepoError:
                print(f'Need authorization to retrieve model size from {modelId}.')
                return None
            except Exception as e:
                print(f"Error retrieving file metadata for {modelId} with extension {ext}: {e}")
                return None  # Return None to indicate failure

    print(f"Could not retrieve model size for {modelId}")
    return None


def retrieve_model_datasets(model):
    """
    Retrieve the datasets used by a given model.

    Args:
        model: The model object.

    Returns:
        A list of datasets used by the model.
    """

    if model.card_data and 'datasets' in model.card_data:
        if type(model.cardData["datasets"]) is list:
            datasets = model.cardData["datasets"]
        else:
            datasets = model.cardData["datasets"]
    else:
        datasets = ['']

    return datasets


def find_datasets_size(datasets):
    """
    Find the size of datasets used by a given model.

    Args:
        datasets: A list of datasets.

    Returns:
        The total size of the datasets or None if not found.
    """

    datasets_size = 0
    if datasets is None:
        return None

    api_token = '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'

    for dataset in datasets:
        try:
            datasets_size += api.dataset_info(dataset,token=api_token).cardData["dataset_info"]["dataset_size"]
        except:
            pass

    return datasets_size


def api_calls_parameters(model):
    """
    Get size, datasets size, and creation date from API calls.

    Args:
        model: The model object.
        datasets: A list of datasets.

    Returns:
        A tuple containing size, datasets_size, and created_at.
    """

    commits = size = created_at = None
    api_token = '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'

    try:
        files = api.list_repo_files(repo_id=model.modelId, token=api_token)
    except GatedRepoError:
        print(
            f'Need authorization to retrieve files and commits from {model.modelId}')
        files = 'needs authorization'
    except Exception as e:
        print(
            f'Unexpected error on retrieving "files" for {model.modelId}:', str(e))
        files = None

    try:
        commits = api.list_repo_commits(repo_id=model.modelId, token=api_token)
        commits = [{**commit.__dict__, "created_at": commit.created_at.strftime(
            '%Y-%m-%dT%H:%M:%S.%fZ')[:-3]+'Z'} for commit in commits]
        created_at = commits[-1]['created_at']
        commits = json.dumps(commits)
    except GatedRepoError:
        commits = 'not authorized'
    except Exception as e:
        print(
            f'Unexpected error on retrieving "commits" for {model.modelId}:', str(e))
        commits = None

    return files, commits, size, created_at


def process_model(model_id):
    """
    Process a model ID and extract relevant information.

    Args:
        model_id: The ID of the model (string).

    Returns:
        A dictionary containing the processed model information.
    """
    datasets_size = None
    datasets = []
    files = commits = size = created_at = model_size = None

    try:
        # Retrieve model metadata
        model_info = api.model_info(repo_id=model_id, token='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')

        # Retrieve datasets
        datasets = retrieve_model_datasets(model_info)
        datasets_size = find_datasets_size(datasets)

        # Retrieve files, commits, size, and creation date
        files, commits, size, created_at = api_calls_parameters(model_info)

        # Calculate model size
        if files:
            model_size = find_model_size(files, model_id)
            print(f"Model {model_id}, Size: {model_size} bytes")
        else:
            print(f"Model {model_id}, Unable to retrieve repo files")

    except Exception as e:
        print(f'Error processing model {model_id}: {str(e)}')

    return {
        'modelId': model_id,
        'size': model_size,
        'datasets': datasets,
        'datasets_size': datasets_size,
        'downloads': model_info.downloads if 'model_info' in locals() else None,
        'likes': model_info.likes if 'model_info' in locals() else None,
        'library_name': model_info.library_name if 'model_info' in locals() else None,
        'created_at': created_at,
        'commits': commits,
        'files': files
    }

# %% [markdown]
# # Models extraction

# %%
import requests
import pandas as pd

# Your API token
api_token = "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"

url = "https://huggingface.co/api/models"

# Set headers with authentication token
headers = {
    "Authorization": f"Bearer {api_token}"
}

# Parameters for pagination
limit = 5000  # Maximum models per request
total_models = 5000  # Total models to fetch
offset = 0
models = []

# Loop to fetch models in batches
while len(models) < total_models:
    params = {
        "limit": limit,
        "offset": offset,
        "sort": "downloads",  # Sort by downloads
        "direction": -1,      # Descending order (-1 for descending)
    }
    response = requests.get(url, headers=headers, params=params)

    # Check for successful response
    if response.status_code == 200:
        model_data = response.json()
        models.extend(model_data)
        
        # Stop if fewer than requested models are returned (end of list)
        if len(model_data) < limit:
            break
    else:
        print(f"Failed to fetch data: {response.status_code} - {response.text}")
        break
    
    # Update offset for the next batch
    offset += limit

# Truncate the list to exactly 400 models if necessary
models = models[:total_models]

# Extract model IDs or other attributes (e.g., 'modelId', 'downloads') into an array
top_models = [{"modelId": model["modelId"], "downloads": model["downloads"]} for model in models]

# Output the array of top models
print(len(top_models))
print(top_models)
# Out:
# 1000
# [{'modelId': 'sentence-transformers/all-mpnet-base-v2', 'downloads': 296552424}, {'modelId': 'nesaorg/benchmark_v0', 'downloads': 118617403}, {'modelId': 'sentence-transformers/all-MiniLM-L6-v2', 'downloads': 99334920}, {'modelId': 'FacebookAI/xlm-roberta-large', 'downloads': 72928929}, {'modelId': 'google-bert/bert-base-uncased', 'downloads': 70401215}, {'modelId': 'Qwen/Qwen2.5-1.5B-Instruct', 'downloads': 43395422}, {'modelId': 'nesaorg/fc_8', 'downloads': 37152421}, {'modelId': 'microsoft/resnet-50', 'downloads': 31051253}, {'modelId': 'openai/clip-vit-large-patch14', 'downloads': 29787899}, {'modelId': 'nesaorg/fc_6', 'downloads': 24655433}, {'modelId': 'openai/clip-vit-base-patch32', 'downloads': 21801468}, {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-english', 'downloads': 21139889}, {'modelId': 'openai/clip-vit-large-patch14-336', 'downloads': 21096806}, {'modelId': 'nesaorg/fc_12', 'downloads': 20024791}, {'modelId': 'FacebookAI/roberta-base', 'downloads': 19326431}, {'modelId': 'facebook/opt-1.3b', 'downloads': 18146887}, {'modelId': 'openai-community/gpt2', 'downloads': 16632300}, {'modelId': 'bigscience/bloomz-560m', 'downloads': 15217373}, {'modelId': 'google/vit-base-patch16-224-in21k', 'downloads': 15187661}, {'modelId': 'timm/resnet50.a1_in1k', 'downloads': 15160276}, {'modelId': 'distilbert/distilbert-base-uncased', 'downloads': 14891526}, {'modelId': 'pyannote/segmentation-3.0', 'downloads': 14669060}, {'modelId': 'openai/clip-vit-base-patch16', 'downloads': 13706113}, {'modelId': 'FacebookAI/roberta-large', 'downloads': 13550776}, {'modelId': 'pyannote/wespeaker-voxceleb-resnet34-LM', 'downloads': 12732452}, {'modelId': 'nesaorg/fc_4', 'downloads': 12224117}, {'modelId': 'FacebookAI/xlm-roberta-base', 'downloads': 11365851}, {'modelId': 'pyannote/speaker-diarization-3.1', 'downloads': 11313087}, {'modelId': 'M-CLIP/XLM-Roberta-Large-Vit-B-32', 'downloads': 11061001}, {'modelId': 'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2', 'downloads': 10898350}, {'modelId': 'sentence-transformers/all-MiniLM-L12-v2', 'downloads': 10682512}, {'modelId': 'bartowski/Meta-Llama-3.1-8B-Instruct-GGUF', 'downloads': 10609739}, {'modelId': 'openai/whisper-small', 'downloads': 10431287}, {'modelId': 'google/electra-base-discriminator', 'downloads': 10340979}, {'modelId': 'nesaorg/fc_16', 'downloads': 9633760}, {'modelId': 'distilbert/distilbert-base-uncased-finetuned-sst-2-english', 'downloads': 9521648}, {'modelId': 'google-bert/bert-base-multilingual-uncased', 'downloads': 9139435}, {'modelId': 'princeton-nlp/sup-simcse-roberta-large', 'downloads': 8879961}, {'modelId': 'CIDAS/clipseg-rd64-refined', 'downloads': 7998214}, {'modelId': 'google-t5/t5-small', 'downloads': 7686905}, {'modelId': 'facebook/dinov2-base', 'downloads': 7527210}, {'modelId': 'google-bert/bert-base-cased', 'downloads': 7403249}, {'modelId': 'google-bert/bert-base-multilingual-cased', 'downloads': 7356982}, {'modelId': 'sentence-transformers/paraphrase-MiniLM-L6-v2', 'downloads': 7241010}, {'modelId': 'pyannote/segmentation', 'downloads': 6870265}, {'modelId': 'albert/albert-base-v2', 'downloads': 6448555}, {'modelId': 'facebook/opt-125m', 'downloads': 6431043}, {'modelId': 'nesaorg/fc_24', 'downloads': 6411428}, {'modelId': 'sentence-transformers/multi-qa-MiniLM-L6-cos-v1', 'downloads': 6322676}, {'modelId': 'meta-llama/Llama-3.1-8B-Instruct', 'downloads': 6192025}, {'modelId': 'pyannote/speaker-diarization', 'downloads': 5958145}, {'modelId': 'adsabs/astroBERT', 'downloads': 5922722}, {'modelId': 'BAAI/bge-small-en-v1.5', 'downloads': 5906373}, {'modelId': 'nesaorg/fc_2', 'downloads': 5338736}, {'modelId': 'microsoft/deberta-base', 'downloads': 5262326}, {'modelId': 'facebook/bart-large-cnn', 'downloads': 5219063}, {'modelId': 'laion/CLIP-ViT-B-16-laion2B-s34B-b88K', 'downloads': 5181733}, {'modelId': 'HuggingFaceM4/siglip-so400m-14-384', 'downloads': 5167375}, {'modelId': 'WinKawaks/vit-tiny-patch16-224', 'downloads': 4954083}, {'mode ...

# %%
top_models
# Out:
# [{'modelId': 'sentence-transformers/all-mpnet-base-v2',
#   'downloads': 296552424},
#  {'modelId': 'nesaorg/benchmark_v0', 'downloads': 118617403},
#  {'modelId': 'sentence-transformers/all-MiniLM-L6-v2', 'downloads': 99334920},
#  {'modelId': 'FacebookAI/xlm-roberta-large', 'downloads': 72928929},
#  {'modelId': 'google-bert/bert-base-uncased', 'downloads': 70401215},
#  {'modelId': 'Qwen/Qwen2.5-1.5B-Instruct', 'downloads': 43395422},
#  {'modelId': 'nesaorg/fc_8', 'downloads': 37152421},
#  {'modelId': 'microsoft/resnet-50', 'downloads': 31051253},
#  {'modelId': 'openai/clip-vit-large-patch14', 'downloads': 29787899},
#  {'modelId': 'nesaorg/fc_6', 'downloads': 24655433},
#  {'modelId': 'openai/clip-vit-base-patch32', 'downloads': 21801468},
#  {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-english',
#   'downloads': 21139889},
#  {'modelId': 'openai/clip-vit-large-patch14-336', 'downloads': 21096806},
#  {'modelId': 'nesaorg/fc_12', 'downloads': 20024791},
#  {'modelId': 'FacebookAI/roberta-base', 'downloads': 19326431},
#  {'modelId': 'facebook/opt-1.3b', 'downloads': 18146887},
#  {'modelId': 'openai-community/gpt2', 'downloads': 16632300},
#  {'modelId': 'bigscience/bloomz-560m', 'downloads': 15217373},
#  {'modelId': 'google/vit-base-patch16-224-in21k', 'downloads': 15187661},
#  {'modelId': 'timm/resnet50.a1_in1k', 'downloads': 15160276},
#  {'modelId': 'distilbert/distilbert-base-uncased', 'downloads': 14891526},
#  {'modelId': 'pyannote/segmentation-3.0', 'downloads': 14669060},
#  {'modelId': 'openai/clip-vit-base-patch16', 'downloads': 13706113},
#  {'modelId': 'FacebookAI/roberta-large', 'downloads': 13550776},
#  {'modelId': 'pyannote/wespeaker-voxceleb-resnet34-LM', 'downloads': 12732452},
#  {'modelId': 'nesaorg/fc_4', 'downloads': 12224117},
#  {'modelId': 'FacebookAI/xlm-roberta-base', 'downloads': 11365851},
#  {'modelId': 'pyannote/speaker-diarization-3.1', 'downloads': 11313087},
#  {'modelId': 'M-CLIP/XLM-Roberta-Large-Vit-B-32', 'downloads': 11061001},
#  {'modelId': 'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2',
#   'downloads': 10898350},
#  {'modelId': 'sentence-transformers/all-MiniLM-L12-v2', 'downloads': 10682512},
#  {'modelId': 'bartowski/Meta-Llama-3.1-8B-Instruct-GGUF',
#   'downloads': 10609739},
#  {'modelId': 'openai/whisper-small', 'downloads': 10431287},
#  {'modelId': 'google/electra-base-discriminator', 'downloads': 10340979},
#  {'modelId': 'nesaorg/fc_16', 'downloads': 9633760},
#  {'modelId': 'distilbert/distilbert-base-uncased-finetuned-sst-2-english',
#   'downloads': 9521648},
#  {'modelId': 'google-bert/bert-base-multilingual-uncased',
#   'downloads': 9139435},
#  {'modelId': 'princeton-nlp/sup-simcse-roberta-large', 'downloads': 8879961},
#  {'modelId': 'CIDAS/clipseg-rd64-refined', 'downloads': 7998214},
#  {'modelId': 'google-t5/t5-small', 'downloads': 7686905},
#  {'modelId': 'facebook/dinov2-base', 'downloads': 7527210},
#  {'modelId': 'google-bert/bert-base-cased', 'downloads': 7403249},
#  {'modelId': 'google-bert/bert-base-multilingual-cased', 'downloads': 7356982},
#  {'modelId': 'sentence-transformers/paraphrase-MiniLM-L6-v2',
#   'downloads': 7241010},
#  {'modelId': 'pyannote/segmentation', 'downloads': 6870265},
#  {'modelId': 'albert/albert-base-v2', 'downloads': 6448555},
#  {'modelId': 'facebook/opt-125m', 'downloads': 6431043},
#  {'modelId': 'nesaorg/fc_24', 'downloads': 6411428},
#  {'modelId': 'sentence-transformers/multi-qa-MiniLM-L6-cos-v1',
#   'downloads': 6322676},
#  {'modelId': 'meta-llama/Llama-3.1-8B-Instruct', 'downloads': 6192025},
#  {'modelId': 'pyannote/speaker-diarization', 'downloads': 5958145},
#  {'modelId': 'adsabs/astroBERT', 'downloads': 5922722},
#  {'modelId': 'BAAI/bge-small-en-v1.5', 'downloads': 5906373},
#  {'modelId': 'nesaorg/fc_2', 'downloads': 5338736},
#  {'modelId': 'microsoft/deberta-base', 'downloads': 5262326},
#  {'modelId': 'facebook/bart-large-cnn', 'downloads': 5219063},
#  {'modelId': 'laion/CLIP-ViT-B-16-laion2B-s34B-b88K', 'downloads': 5181733},
#  {'modelId': 'HuggingFaceM4/siglip-so400m-14-384', 'downloads': 5167375},
#  {'modelId': 'WinKawaks/vit-tiny-patch16-224', 'downloads': 4954083},
#  {'modelId': 'cardiffnlp/twitter-roberta-base-sentiment-latest',
#   'downloads': 4822677},
#  {'modelId': 'papluca/xlm-roberta-base-language-detection',
#   'downloads': 4702539},
#  {'modelId': 'sentence-transformers/bert-base-nli-mean-tokens',
#   'downloads': 4647182},
#  {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-portuguese',
#   'downloads': 4602613},
#  {'modelId': 'stable-diffusion-v1-5/stable-diffusion-inpainting',
#   'downloads': 4565834},
#  {'modelId': 'facebook/fasttext-language-identification',
#   'downloads': 4518629},
#  {'modelId': 'distributed/optimized-gpt2-1b', 'downloads': 4471565},
#  {'modelId': 'emilyalsentzer/Bio_ClinicalBERT', 'downloads': 4469626},
#  {'modelId': 'allenai/longformer-base-4096', 'downloads': 4402761},
#  {'modelId': 'microsoft/deberta-v3-large', 'downloads': 4226859},
#  {'modelId': 'Falconsai/nsfw_image_detection', 'downloads': 4121724},
#  {'modelId': 'neuralmind/bert-base-portuguese-cased', 'downloads': 4073693},
#  {'modelId': 'stable-diffusion-v1-5/stable-diffusion-v1-5',
#   'downloads': 4067292},
#  {'modelId': 'amazon/chronos-t5-small', 'downloads': 3958699},
#  {'modelId': 'facebook/wav2vec2-xls-r-300m', 'downloads': 3830442},
#  {'modelId': 'mattmdjaga/segformer_b2_clothes', 'downloads': 3807104},
#  {'modelId': 'google/vit-base-patch16-224', 'downloads': 3759330},
#  {'modelId': 'FacebookAI/xlm-roberta-large-finetuned-conll03-english',
#   'downloads': 3725746},
#  {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-russian',
#   'downloads': 3714632},
#  {'modelId': 'openai/whisper-large-v3', 'downloads': 3666606},
#  {'modelId': 'MIT/ast-finetuned-audioset-10-10-0.4593', 'downloads': 3542023},
#  {'modelId': 'facebook/bart-large-mnli', 'downloads': 3304056},
#  {'modelId': 'answerdotai/answerai-colbert-small-v1', 'downloads': 3298255},
#  {'modelId': 'mixedbread-ai/mxbai-embed-large-v1', 'downloads': 3296110},
#  {'modelId': 'facebook/bart-base', 'downloads': 3217722},
#  {'modelId': 'Minej/bert-base-personality', 'downloads': 3208905},
#  {'modelId': 'BAAI/bge-base-en-v1.5', 'downloads': 3159195},
#  {'modelId': 'BAAI/bge-large-en-v1.5', 'downloads': 3089761},
#  {'modelId': 'google/siglip-so400m-patch14-384', 'downloads': 3038118},
#  {'modelId': 'microsoft/table-transformer-detection', 'downloads': 3026009},
#  {'modelId': 'microsoft/infoxlm-large', 'downloads': 2996676},
#  {'modelId': 'BAAI/bge-m3', 'downloads': 2987285},
#  {'modelId': 'Alibaba-NLP/gte-large-en-v1.5', 'downloads': 2863251},
#  {'modelId': 'w11wo/indonesian-roberta-base-posp-tagger',
#   'downloads': 2837932},
#  {'modelId': 'pyannote/speaker-diarization-3.0', 'downloads': 2833839},
#  {'modelId': 'patrickjohncyh/fashion-clip', 'downloads': 2772896},
#  {'modelId': 'unslothai/1', 'downloads': 2725373},
#  {'modelId': 'nesaorg/fc_1', 'downloads': 2715378},
#  {'modelId': 'Moritz-Pfeifer/CentralBankRoBERTa-sentiment-classifier',
#   'downloads': 2712545},
#  {'modelId': 'cross-encoder/ms-marco-MiniLM-L-6-v2', 'downloads': 2711635},
#  {'modelId': 'ntu-spml/distilhubert', 'downloads': 2701680},
#  {'modelId': 'meta-llama/Meta-Llama-3-8B-Instruct', 'downloads': 2694184},
#  {'modelId': 'distilbert/distilroberta-base', 'downloads': 2693279},
#  {'modelId': 'stabilityai/stable-diffusion-xl-base-1.0', 'downloads': 2692090},
#  {'modelId': 'google-t5/t5-base', 'downloads': 2647206},
#  {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-dutch',
#   'downloads': 2639172},
#  {'modelId': 'openai/whisper-large-v3-turbo', 'downloads': 2518444},
#  {'modelId': 'cardiffnlp/twitter-xlm-roberta-base-sentiment-multilingual',
#   'downloads': 2511893},
#  {'modelId': 'facebook/roberta-hate-speech-dynabench-r4-target',
#   'downloads': 2466718},
#  {'modelId': 'microsoft/layoutlm-base-uncased', 'downloads': 2460950},
#  {'modelId': 'Qwen/Qwen2-VL-7B-Instruct', 'downloads': 2452030},
#  {'modelId': 'lxyuan/distilbert-base-multilingual-cased-sentiments-student',
#   'downloads': 2429358},
#  {'modelId': 'nvidia/speakerverification_en_titanet_large',
#   'downloads': 2379048},
#  {'modelId': 'sentence-transformers/all-distilroberta-v1',
#   'downloads': 2357382},
#  {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-chinese-zh-cn',
#   'downloads': 2333035},
#  {'modelId': 'pyannote/embedding', 'downloads': 2327786},
#  {'modelId': 'WinKawaks/vit-small-patch16-224', 'downloads': 2309523},
#  {'modelId': 'tohoku-nlp/bert-base-japanese', 'downloads': 2296622},
#  {'modelId': 'distilbert/distilgpt2', 'downloads': 2263690},
#  {'modelId': 'timm/resnet18.a1_in1k', 'downloads': 2248520},
#  {'modelId': 'google-bert/bert-large-uncased', 'downloads': 2228465},
#  {'modelId': 'google/byt5-small', 'downloads': 2182102},
#  {'modelId': 'prs-eth/marigold-normals-lcm-v0-1', 'downloads': 2165313},
#  {'modelId': 'meta-llama/Llama-3.2-11B-Vision-Instruct', 'downloads': 2163576},
#  {'modelId': 'cardiffnlp/twitter-roberta-base-sentiment',
#   'downloads': 2160812},
#  {'modelId': 'cointegrated/rubert-tiny', 'downloads': 2141344},
#  {'modelId': 'TinyLlama/TinyLlama-1.1B-Chat-v1.0', 'downloads': 2135422},
#  {'modelId': 'nlpconnect/vit-gpt2-image-captioning', 'downloads': 2132878},
#  {'modelId': 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2',
#   'downloads': 2128959},
#  {'modelId': 'dslim/bert-base-NER', 'downloads': 2108947},
#  {'modelId': 'facebook/esm2_t36_3B_UR50D', 'downloads': 2100748},
#  {'modelId': 'microsoft/git-base', 'downloads': 2072264},
#  {'modelId': 'almanach/camembert-base', 'downloads': 2063022},
#  {'modelId': 'meta-llama/Llama-3.1-70B-Instruct', 'downloads': 2054140},
#  {'modelId': 'autogluon/chronos-t5-tiny', 'downloads': 2050285},
#  {'modelId': 'prajjwal1/bert-small', 'downloads': 1992783},
#  {'modelId': 'Salesforce/blip-image-captioning-large', 'downloads': 1969484},
#  {'modelId': 'BAAI/bge-reranker-large', 'downloads': 1927230},
#  {'modelId': 'thenlper/gte-large', 'downloads': 1920169},
#  {'modelId': 'microsoft/beit-base-patch16-224-pt22k-ft22k',
#   'downloads': 1912383},
#  {'modelId': 'MaziyarPanahi/Mistral-7B-Instruct-v0.3-GGUF',
#   'downloads': 1908635},
#  {'modelId': 'MaziyarPanahi/Meta-Llama-3-8B-Instruct-GGUF',
#   'downloads': 1900178},
#  {'modelId': 'MaziyarPanahi/Llama-3-8B-Instruct-32k-v0.1-GGUF',
#   'downloads': 1892040},
#  {'modelId': 'cambridgeltl/SapBERT-from-PubMedBERT-fulltext',
#   'downloads': 1862750},
#  {'modelId': 'amazon/chronos-t5-tiny', 'downloads': 1837518},
#  {'modelId': 'MaziyarPanahi/WizardLM-2-7B-GGUF', 'downloads': 1833979},
#  {'modelId': 'Cloudy1225/stackoverflow-roberta-base-sentiment',
#   'downloads': 1827261},
#  {'modelId': 'coqui/XTTS-v2', 'downloads': 1825667},
#  {'modelId': 'ProsusAI/finbert', 'downloads': 1812004},
#  {'modelId': 'meta-llama/Llama-3.2-1B', 'downloads': 1811588},
#  {'modelId': 'BAAI/bge-large-zh-v1.5', 'downloads': 1809806},
#  {'modelId': 'Qwen/Qwen2-0.5B', 'downloads': 1794821},
#  {'modelId': 'MaziyarPanahi/solar-pro-preview-instruct-GGUF',
#   'downloads': 1787315},
#  {'modelId': 'meta-llama/Llama-3.2-1B-Instruct', 'downloads': 1786289},
#  {'modelId': 'MaziyarPanahi/Llama-3.2-3B-Instruct-GGUF', 'downloads': 1786114},
#  {'modelId': 'MaziyarPanahi/Qwen2-7B-Instruct-GGUF', 'downloads': 1783930},
#  {'modelId': 'MaziyarPanahi/gemma-2-2b-it-GGUF', 'downloads': 1776902},
#  {'modelId': 'MaziyarPanahi/Yi-Coder-9B-Chat-GGUF', 'downloads': 1776386},
#  {'modelId': 'google/gemma-2-2b', 'downloads': 1776161},
#  {'modelId': 'MaziyarPanahi/Mistral-Nemo-Instruct-2407-GGUF',
#   'downloads': 1773805},
#  {'modelId': 'MaziyarPanahi/Meta-Llama-3.1-70B-Instruct-GGUF',
#   'downloads': 1773741},
#  {'modelId': 'MaziyarPanahi/Qwen2.5-7B-Instruct-GGUF', 'downloads': 1770508},
#  {'modelId': 'MaziyarPanahi/Phi-3.5-mini-instruct-GGUF', 'downloads': 1767664},
#  {'modelId': 'brunopio/Llama3-8B-1.58-100B-tokens-GGUF', 'downloads': 1765867},
#  {'modelId': 'MaziyarPanahi/Yi-1.5-6B-Chat-GGUF', 'downloads': 1765496},
#  {'modelId': 'MaziyarPanahi/Llama-3.2-1B-Instruct-GGUF', 'downloads': 1765189},
#  {'modelId': 'MaziyarPanahi/Qwen2-1.5B-Instruct-GGUF', 'downloads': 1764336},
#  {'modelId': 'MaziyarPanahi/Llama-3-Groq-8B-Tool-Use-GGUF',
#   'downloads': 1764292},
#  {'modelId': 'MaziyarPanahi/Meta-Llama-3.1-8B-Instruct-GGUF',
#   'downloads': 1762953},
#  {'modelId': 'MaziyarPanahi/mathstral-7B-v0.1-GGUF', 'downloads': 1762683},
#  {'modelId': 'MaziyarPanahi/firefunction-v2-GGUF', 'downloads': 1762512},
#  {'modelId': 'MaziyarPanahi/Qwen2.5-1.5B-Instruct-GGUF', 'downloads': 1761165},
#  {'modelId': 'MaziyarPanahi/Yi-Coder-1.5B-Chat-GGUF', 'downloads': 1761151},
#  {'modelId': 'MaziyarPanahi/Llama-3-8B-Instruct-64k-GGUF',
#   'downloads': 1761075},
#  {'modelId': 'nateraw/vit-age-classifier', 'downloads': 1755185},
#  {'modelId': 'google-bert/bert-base-chinese', 'downloads': 1751220},
#  {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-japanese',
#   'downloads': 1745451},
#  {'modelId': 'smallcloudai/Refact-1_6B-fim', 'downloads': 1713867},
#  {'modelId': 'sentence-transformers/multi-qa-mpnet-base-dot-v1',
#   'downloads': 1708133},
#  {'modelId': 'YituTech/conv-bert-base', 'downloads': 1707321},
#  {'modelId': 'google/fnet-base', 'downloads': 1704283},
#  {'modelId': 'nomic-ai/nomic-embed-text-v1.5', 'downloads': 1632427},
#  {'modelId': 'cross-encoder/ms-marco-MiniLM-L-4-v2', 'downloads': 1630046},
#  {'modelId': 'Qwen/Qwen2.5-7B-Instruct', 'downloads': 1623022},
#  {'modelId': 'meta-llama/Llama-3.2-3B-Instruct', 'downloads': 1617014},
#  {'modelId': 'timm/mobilenetv3_large_100.ra_in1k', 'downloads': 1614513},
#  {'modelId': 'microsoft/layoutlmv3-base', 'downloads': 1609989},
#  {'modelId': 'lengyue233/content-vec-best', 'downloads': 1609134},
#  {'modelId': 'deepset/roberta-base-squad2', 'downloads': 1600240},
#  {'modelId': 'microsoft/codebert-base', 'downloads': 1597663},
#  {'modelId': 'Salesforce/blip-image-captioning-base', 'downloads': 1596325},
#  {'modelId': 'kyutai/mimi', 'downloads': 1594775},
#  {'modelId': 'briaai/RMBG-1.4', 'downloads': 1594685},
#  {'modelId': 'MaziyarPanahi/Llama-3-Smaug-8B-GGUF', 'downloads': 1580278},
#  {'modelId': 'black-forest-labs/FLUX.1-schnell', 'downloads': 1559312},
#  {'modelId': 'unslothai/other', 'downloads': 1547132},
#  {'modelId': 'opensearch-project/opensearch-neural-sparse-encoding-doc-v2-distill',
#   'downloads': 1541595},
#  {'modelId': 'colbert-ir/colbertv2.0', 'downloads': 1539807},
#  {'modelId': 'openai/whisper-base.en', 'downloads': 1527539},
#  {'modelId': 'MaziyarPanahi/Llama-3-8B-Instruct-v0.10-GGUF',
#   'downloads': 1518741},
#  {'modelId': 'nlptown/bert-base-multilingual-uncased-sentiment',
#   'downloads': 1518391},
#  {'modelId': 'MaziyarPanahi/Llama-3-8B-Instruct-v0.9-GGUF',
#   'downloads': 1511321},
#  {'modelId': 'rizvandwiki/gender-classification', 'downloads': 1494342},
#  {'modelId': 'owkin/phikon', 'downloads': 1484604},
#  {'modelId': 'intfloat/e5-large-v2', 'downloads': 1476831},
#  {'modelId': 'MaziyarPanahi/calme-2.3-legalkit-8b-GGUF', 'downloads': 1451616},
#  {'modelId': 'google-bert/bert-large-cased', 'downloads': 1415187},
#  {'modelId': 'google/t5-v1_1-xxl', 'downloads': 1404756},
#  {'modelId': 'apple/OpenELM-1_1B-Instruct', 'downloads': 1402013},
#  {'modelId': 'canerturkmen/bolt-test', 'downloads': 1387859},
#  {'modelId': 'prithivida/parrot_paraphraser_on_T5', 'downloads': 1383160},
#  {'modelId': 'microsoft/deberta-v3-base', 'downloads': 1380981},
#  {'modelId': 'charactr/vocos-mel-24khz', 'downloads': 1379860},
#  {'modelId': 'black-forest-labs/FLUX.1-dev', 'downloads': 1379412},
#  {'modelId': 'SamLowe/roberta-base-go_emotions', 'downloads': 1376752},
#  {'modelId': 'google/canine-c', 'downloads': 1362818},
#  {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-arabic',
#   'downloads': 1358060},
#  {'modelId': 'microsoft/Phi-3-mini-4k-instruct', 'downloads': 1343059},
#  {'modelId': 'openai/whisper-medium', 'downloads': 1340418},
#  {'modelId': 'padmajabfrl/Gender-Classification', 'downloads': 1337137},
#  {'modelId': 'MaziyarPanahi/Llama-3-8B-Instruct-DPO-v0.1-GGUF',
#   'downloads': 1333075},
#  {'modelId': 'MaziyarPanahi/Llama-3-8B-Instruct-DPO-v0.2-GGUF',
#   'downloads': 1332976},
#  {'modelId': 'intfloat/multilingual-e5-large', 'downloads': 1331660},
#  {'modelId': 'stabilityai/stable-diffusion-2-1', 'downloads': 1331333},
#  {'modelId': 'liuhaotian/llava-v1.5-7b', 'downloads': 1330247},
#  {'modelId': 'google/flan-t5-large', 'downloads': 1324301},
#  {'modelId': 'google/owlv2-base-patch16-ensemble', 'downloads': 1314912},
#  {'modelId': 'facebook/m2m100_418M', 'downloads': 1311245},
#  {'modelId': 'facebook/wav2vec2-base-960h', 'downloads': 1310705},
#  {'modelId': 'facebook/sam2-hiera-large', 'downloads': 1309688},
#  {'modelId': 'AdamCodd/vit-base-nsfw-detector', 'downloads': 1284389},
#  {'modelId': 'dunzhang/stella_en_400M_v5', 'downloads': 1283983},
#  {'modelId': 'patrickvonplaten/wavlm-libri-clean-100h-base-plus',
#   'downloads': 1280181},
#  {'modelId': 'facebook/wav2vec2-base', 'downloads': 1274492},
#  {'modelId': 'dmis-lab/biobert-v1.1', 'downloads': 1272629},
#  {'modelId': 'IDEA-Research/grounding-dino-tiny', 'downloads': 1264302},
#  {'modelId': 'trl-internal-testing/tiny-random-LlamaForCausalLM',
#   'downloads': 1260425},
#  {'modelId': 'flair/ner-english-fast', 'downloads': 1259467},
#  {'modelId': 'vinid/plip', 'downloads': 1252414},
#  {'modelId': 'openai/whisper-large-v2', 'downloads': 1245597},
#  {'modelId': 'tsmatz/xlm-roberta-ner-japanese', 'downloads': 1243880},
#  {'modelId': 'sentence-transformers/msmarco-distilbert-dot-v5',
#   'downloads': 1228047},
#  {'modelId': 'cross-encoder/ms-marco-TinyBERT-L-2-v2', 'downloads': 1227852},
#  {'modelId': 'WhereIsAI/UAE-Large-V1', 'downloads': 1221906},
#  {'modelId': 'Alibaba-NLP/gte-multilingual-base', 'downloads': 1220942},
#  {'modelId': 'CompVis/stable-diffusion-safety-checker', 'downloads': 1213280},
#  {'modelId': 'MahmoudAshraf/mms-300m-1130-forced-aligner',
#   'downloads': 1191500},
#  {'modelId': 'charsiu/en_w2v2_fc_10ms', 'downloads': 1179307},
#  {'modelId': 'sentence-transformers/all-roberta-large-v1',
#   'downloads': 1159362},
#  {'modelId': 'ashawkey/mvdream-sd2.1-diffusers', 'downloads': 1158143},
#  {'modelId': 'stabilityai/sdxl-turbo', 'downloads': 1148128},
#  {'modelId': 'peft-internal-testing/tiny-dummy-qwen2', 'downloads': 1146573},
#  {'modelId': 'Qwen/Qwen2-VL-2B-Instruct', 'downloads': 1131825},
#  {'modelId': 'mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis',
#   'downloads': 1129034},
#  {'modelId': 'google/bert_uncased_L-2_H-128_A-2', 'downloads': 1124717},
#  {'modelId': 'deepset/roberta-base-squad2-distilled', 'downloads': 1122843},
#  {'modelId': 'thenlper/gte-base', 'downloads': 1121353},
#  {'modelId': 'avsolatorio/GIST-small-Embedding-v0', 'downloads': 1114360},
#  {'modelId': 'pysentimiento/robertuito-sentiment-analysis',
#   'downloads': 1112853},
#  {'modelId': 'yiyanghkust/finbert-tone', 'downloads': 1109081},
#  {'modelId': 'CompVis/stable-diffusion-v1-4', 'downloads': 1107203},
#  {'modelId': 'nvidia/segformer-b1-finetuned-ade-512-512',
#   'downloads': 1101801},
#  {'modelId': 'ybelkada/tiny-random-T5ForConditionalGeneration-calibrated',
#   'downloads': 1083404},
#  {'modelId': 'jhgan/ko-sroberta-multitask', 'downloads': 1080405},
#  {'modelId': 'RunDiffusion/Juggernaut-XL-v9', 'downloads': 1076519},
#  {'modelId': 'j-hartmann/emotion-english-distilroberta-base',
#   'downloads': 1070563},
#  {'modelId': 'BAAI/bge-reranker-base', 'downloads': 1057055},
#  {'modelId': 'gilf/french-camembert-postag-model', 'downloads': 1034105},
#  {'modelId': 'T-Systems-onsite/cross-en-de-roberta-sentence-transformer',
#   'downloads': 1030271},
#  {'modelId': 'dbmdz/bert-large-cased-finetuned-conll03-english',
#   'downloads': 1022515},
#  {'modelId': 'openai-community/gpt2-large', 'downloads': 1013745},
#  {'modelId': 'vikp/surya_det3', 'downloads': 1004027},
#  {'modelId': 'meta-llama/Llama-3.1-8B', 'downloads': 984240},
#  {'modelId': 'microsoft/table-transformer-structure-recognition',
#   'downloads': 974932},
#  {'modelId': 'stabilityai/stable-diffusion-2-1-base', 'downloads': 965264},
#  {'modelId': 'trl-internal-testing/dummy-GPT2-correct-vocab',
#   'downloads': 960386},
#  {'modelId': 'ai-forever/sbert_large_nlu_ru', 'downloads': 959269},
#  {'modelId': 'microsoft/Phi-3-mini-128k-instruct', 'downloads': 933087},
#  {'modelId': 'unitary/toxic-bert', 'downloads': 928582},
#  {'modelId': 'microsoft/trocr-base-handwritten', 'downloads': 927877},
#  {'modelId': 'stepfun-ai/GOT-OCR2_0', 'downloads': 926311},
#  {'modelId': 'myshell-ai/MeloTTS-English', 'downloads': 925777},
#  {'modelId': 'Helsinki-NLP/opus-mt-fr-en', 'downloads': 920864},
#  {'modelId': 'meta-llama/Llama-2-7b-hf', 'downloads': 911984},
#  {'modelId': 'michellejieli/emotion_text_classifier', 'downloads': 908529},
#  {'modelId': 'shibing624/text2vec-base-chinese', 'downloads': 904642},
#  {'modelId': 'intfloat/multilingual-e5-small', 'downloads': 903474},
#  {'modelId': 'Helsinki-NLP/opus-mt-zh-en', 'downloads': 902319},
#  {'modelId': 'unslothai/vram-24', 'downloads': 895506},
#  {'modelId': 'cointegrated/rubert-tiny2', 'downloads': 893065},
#  {'modelId': 'facebook/sam-vit-base', 'downloads': 883812},
#  {'modelId': 'Shakker-Labs/FLUX.1-dev-LoRA-AntiBlur', 'downloads': 881758},
#  {'modelId': 'thenlper/gte-small', 'downloads': 876402},
#  {'modelId': 'vikp/surya_rec2', 'downloads': 875206},
#  {'modelId': 'Xenova/bge-base-en-v1.5', 'downloads': 874869},
#  {'modelId': 'Hate-speech-CNERG/tamil-codemixed-abusive-MuRIL',
#   'downloads': 874656},
#  {'modelId': 'prajjwal1/bert-tiny', 'downloads': 869843},
#  {'modelId': 'laion/CLIP-ViT-H-14-laion2B-s32B-b79K', 'downloads': 862284},
#  {'modelId': 'unsloth/llama-3-8b-bnb-4bit', 'downloads': 852740},
#  {'modelId': 'microsoft/table-transformer-structure-recognition-v1.1-all',
#   'downloads': 850577},
#  {'modelId': 'laion/CLIP-ViT-B-32-laion2B-s34B-b79K', 'downloads': 849730},
#  {'modelId': 'Hate-speech-CNERG/english-abusive-MuRIL', 'downloads': 846478},
#  {'modelId': 'allenai/scibert_scivocab_uncased', 'downloads': 840483},
#  {'modelId': 'BridgeTower/bridgetower-large-itm-mlm-itc', 'downloads': 840068},
#  {'modelId': 'nvidia/parakeet-rnnt-1.1b', 'downloads': 839624},
#  {'modelId': 'obi/deid_roberta_i2b2', 'downloads': 837751},
#  {'modelId': 'openai/whisper-base', 'downloads': 829323},
#  {'modelId': 'sshleifer/distilbart-cnn-12-6', 'downloads': 822235},
#  {'modelId': 'microsoft/Phi-3.5-vision-instruct', 'downloads': 822046},
#  {'modelId': 'MoritzLaurer/DeBERTa-v3-base-mnli-fever-anli',
#   'downloads': 814422},
#  {'modelId': 'meta-llama/Llama-2-7b-chat-hf', 'downloads': 811174},
#  {'modelId': 'unslothai/repeat', 'downloads': 811166},
#  {'modelId': 'jinaai/jina-embeddings-v3', 'downloads': 811009},
#  {'modelId': 'csebuetnlp/banglat5_banglaparaphrase', 'downloads': 802675},
#  {'modelId': 'naver/splade-cocondenser-selfdistil', 'downloads': 800413},
#  {'modelId': 'nvidia/dragon-multiturn-context-encoder', 'downloads': 791117},
#  {'modelId': 'nvidia/dragon-multiturn-query-encoder', 'downloads': 790741},
#  {'modelId': 'sentence-transformers/distilbert-base-nli-stsb-mean-tokens',
#   'downloads': 785327},
#  {'modelId': 'Helsinki-NLP/opus-mt-mul-en', 'downloads': 778211},
#  {'modelId': 'meta-llama/Llama-3.2-3B', 'downloads': 777651},
#  {'modelId': 'ZhengPeng7/BiRefNet', 'downloads': 773726},
#  {'modelId': 'BAAI/bge-large-en', 'downloads': 764904},
#  {'modelId': 'facebook/esmfold_v1', 'downloads': 764142},
#  {'modelId': 'indobenchmark/indobert-base-p1', 'downloads': 764134},
#  {'modelId': 'modularai/llama-3.1', 'downloads': 763932},
#  {'modelId': 'microsoft/mdeberta-v3-base', 'downloads': 763833},
#  {'modelId': 'facebook/dinov2-large', 'downloads': 761446},
#  {'modelId': 'yikuan8/Clinical-Longformer', 'downloads': 760503},
#  {'modelId': 'BAAI/bge-small-en', 'downloads': 759614},
#  {'modelId': 'sentence-transformers/stsb-xlm-r-multilingual',
#   'downloads': 758900},
#  {'modelId': 'dslim/bert-base-NER-uncased', 'downloads': 754662},
#  {'modelId': 'sentence-transformers/distiluse-base-multilingual-cased-v1',
#   'downloads': 751861},
#  {'modelId': 'Helsinki-NLP/opus-mt-ar-en', 'downloads': 750455},
#  {'modelId': 'cambridgeltl/SapBERT-UMLS-2020AB-all-lang-from-XLMR',
#   'downloads': 749588},
#  {'modelId': 'martin-ha/toxic-comment-model', 'downloads': 747499},
#  {'modelId': 'google/owlvit-base-patch32', 'downloads': 746220},
#  {'modelId': 'hustvl/vitmatte-small-composition-1k', 'downloads': 743871},
#  {'modelId': 'aubmindlab/bert-base-arabertv02', 'downloads': 743518},
#  {'modelId': 'microsoft/deberta-v3-small', 'downloads': 742989},
#  {'modelId': 'facebook/contriever', 'downloads': 742064},
#  {'modelId': 'llava-hf/llava-v1.6-mistral-7b-hf', 'downloads': 738045},
#  {'modelId': 'speechbrain/spkrec-ecapa-voxceleb', 'downloads': 735779},
#  {'modelId': 'facebook/detr-resnet-50', 'downloads': 734840},
#  {'modelId': 'Isotr0py/test-gguf-sample', 'downloads': 732962},
#  {'modelId': 'trpakov/vit-face-expression', 'downloads': 730594},
#  {'modelId': 'BAAI/bge-reranker-v2-m3', 'downloads': 730421},
#  {'modelId': 'MaziyarPanahi/SmolLM-1.7B-Instruct-v0.2-GGUF',
#   'downloads': 726816},
#  {'modelId': 'MaziyarPanahi/SmolLM2-1.7B-Instruct-GGUF', 'downloads': 726160},
#  {'modelId': 'deepdml/faster-whisper-large-v3-turbo-ct2', 'downloads': 726085},
#  {'modelId': 'MaziyarPanahi/SmolLM2-135M-Instruct-GGUF', 'downloads': 725729},
#  {'modelId': 'THUDM/chatglm2-6b', 'downloads': 721614},
#  {'modelId': 'autogluon/chronos-t5-mini', 'downloads': 718201},
#  {'modelId': 'sentence-transformers/stsb-roberta-base', 'downloads': 717418},
#  {'modelId': 'sentence-transformers/distiluse-base-multilingual-cased-v2',
#   'downloads': 708805},
#  {'modelId': 'IDEA-Research/grounding-dino-base', 'downloads': 706854},
#  {'modelId': 'meta-llama/Meta-Llama-3-8B', 'downloads': 699149},
#  {'modelId': 'JackFram/llama-68m', 'downloads': 695501},
#  {'modelId': 'Helsinki-NLP/opus-mt-en-fr', 'downloads': 694202},
#  {'modelId': 'jbetker/wav2vec2-large-robust-ft-libritts-voxpopuli',
#   'downloads': 692156},
#  {'modelId': 'SWivid/F5-TTS', 'downloads': 683883},
#  {'modelId': 'cross-encoder/ms-marco-MiniLM-L-12-v2', 'downloads': 682096},
#  {'modelId': 'Systran/faster-whisper-large-v3', 'downloads': 681329},
#  {'modelId': 'Tochka-AI/ruRoPEBert-e5-base-2k', 'downloads': 672103},
#  {'modelId': 'MMG/xlm-roberta-large-ner-spanish', 'downloads': 664745},
#  {'modelId': 'sentence-transformers/roberta-base-nli-mean-tokens',
#   'downloads': 664412},
#  {'modelId': 'SG161222/RealVisXL_V4.0', 'downloads': 662825},
#  {'modelId': 'avsolatorio/GIST-Embedding-v0', 'downloads': 662188},
#  {'modelId': 'google/gemma-2-2b-it', 'downloads': 660827},
#  {'modelId': 'google/flan-t5-base', 'downloads': 658134},
#  {'modelId': 'mistralai/Mistral-7B-Instruct-v0.3', 'downloads': 642206},
#  {'modelId': 'timm/efficientnet_b0.ra_in1k', 'downloads': 641858},
#  {'modelId': 'naver/splade-cocondenser-ensembledistil', 'downloads': 640991},
#  {'modelId': 'microsoft/Florence-2-large', 'downloads': 640442},
#  {'modelId': 'cardiffnlp/twitter-xlm-roberta-base-sentiment',
#   'downloads': 639669},
#  {'modelId': 'google/flan-t5-xxl', 'downloads': 639185},
#  {'modelId': 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit',
#   'downloads': 637270},
#  {'modelId': 'Danswer/intent-model', 'downloads': 631321},
#  {'modelId': 'kresnik/wav2vec2-large-xlsr-korean', 'downloads': 627208},
#  {'modelId': 'llava-hf/llava-1.5-7b-hf', 'downloads': 626645},
#  {'modelId': 'sentence-transformers/paraphrase-mpnet-base-v2',
#   'downloads': 625265},
#  {'modelId': 'sentence-transformers/msmarco-distilbert-base-v4',
#   'downloads': 623151},
#  {'modelId': 'Qwen/Qwen2.5-0.5B-Instruct', 'downloads': 622645},
#  {'modelId': 'Helsinki-NLP/opus-mt-en-zh', 'downloads': 621497},
#  {'modelId': 'Ashishkr/query_wellformedness_score', 'downloads': 620296},
#  {'modelId': 'mistralai/Mistral-7B-Instruct-v0.2', 'downloads': 619865},
#  {'modelId': 'EmergentMethods/gliner_medium_news-v2.1', 'downloads': 611726},
#  {'modelId': 'nomic-ai/nomic-embed-text-v1', 'downloads': 607487},
#  {'modelId': 'microsoft/wavlm-base-plus', 'downloads': 601223},
#  {'modelId': 'google/gemma-2-27b', 'downloads': 600496},
#  {'modelId': 'huggyllama/llama-7b', 'downloads': 598229},
#  {'modelId': 'microsoft/dit-base', 'downloads': 597269},
#  {'modelId': 'stabilityai/stable-diffusion-2-inpainting', 'downloads': 597035},
#  {'modelId': 'facebook/esm2_t6_8M_UR50D', 'downloads': 595911},
#  {'modelId': 'blanchefort/rubert-base-cased-sentiment-rusentiment',
#   'downloads': 594529},
#  {'modelId': 'facebook/encodec_24khz', 'downloads': 592929},
#  {'modelId': 'stabilityai/stable-diffusion-xl-refiner-1.0',
#   'downloads': 582227},
#  {'modelId': '1-800-BAD-CODE/punctuation_fullstop_truecase_english',
#   'downloads': 578464},
#  {'modelId': 'trl-internal-testing/tiny-Qwen2ForCausalLM-2.5',
#   'downloads': 574922},
#  {'modelId': 'kredor/punctuate-all', 'downloads': 574429},
#  {'modelId': 'avsolatorio/GIST-large-Embedding-v0', 'downloads': 572992},
#  {'modelId': 'prithivida/Splade_PP_en_v1', 'downloads': 571136},
#  {'modelId': 'google/vivit-b-16x2', 'downloads': 568599},
#  {'modelId': 'MattyB95/AST-VoxCelebSpoof-Synthetic-Voice-Detection',
#   'downloads': 567561},
#  {'modelId': 'Rostlab/prot_bert', 'downloads': 567444},
#  {'modelId': 'Qwen/Qwen1.5-0.5B-Chat', 'downloads': 566614},
#  {'modelId': 'amazon/chronos-t5-large', 'downloads': 559530},
#  {'modelId': 'theainerd/Wav2Vec2-large-xlsr-hindi', 'downloads': 552799},
#  {'modelId': 'hpcai-tech/OpenSora-VAE-v1.2', 'downloads': 552352},
#  {'modelId': 'ai4bharat/indic-bert', 'downloads': 545852},
#  {'modelId': 'mpoyraz/wav2vec2-xls-r-300m-cv7-turkish', 'downloads': 541340},
#  {'modelId': 'microsoft/trocr-small-handwritten', 'downloads': 537839},
#  {'modelId': 'xiaxy/elastic-bert-chinese-ner', 'downloads': 536903},
#  {'modelId': 'Supabase/gte-small', 'downloads': 536325},
#  {'modelId': 'google/flan-t5-small', 'downloads': 536111},
#  {'modelId': 'openai-community/gpt2-medium', 'downloads': 531646},
#  {'modelId': 'unslothai/vram-16', 'downloads': 531060},
#  {'modelId': 'Helsinki-NLP/opus-mt-es-en', 'downloads': 527959},
#  {'modelId': 'microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract',
#   'downloads': 526717},
#  {'modelId': 'google/gemma-7b-it', 'downloads': 526065},
#  {'modelId': 'qanastek/51-languages-classifier', 'downloads': 525164},
#  {'modelId': 'flair/ner-english-large', 'downloads': 523278},
#  {'modelId': 'finiteautomata/beto-sentiment-analysis', 'downloads': 522250},
#  {'modelId': 'autogluon/chronos-t5-large', 'downloads': 520763},
#  {'modelId': 'Qwen/Qwen2-7B-Instruct', 'downloads': 518318},
#  {'modelId': 'TheBloke/Mistral-7B-Instruct-v0.2-GPTQ', 'downloads': 517061},
#  {'modelId': 'facebook/esm2_t33_650M_UR50D', 'downloads': 516024},
#  {'modelId': 'OpenAssistant/oasst-sft-4-pythia-12b-epoch-3.5',
#   'downloads': 515680},
#  {'modelId': 'shi-labs/oneformer_coco_swin_large', 'downloads': 513966},
#  {'modelId': 'timm/vit_base_patch16_224.mae', 'downloads': 513796},
#  {'modelId': 'amunchet/rorshark-vit-base', 'downloads': 512923},
#  {'modelId': 'timm/ViT-L-16-SigLIP-384', 'downloads': 510757},
#  {'modelId': 'seara/rubert-tiny2-russian-sentiment', 'downloads': 510707},
#  {'modelId': 'Systran/faster-whisper-large-v2', 'downloads': 510033},
#  {'modelId': 'sentence-transformers/msmarco-distilbert-base-tas-b',
#   'downloads': 509919},
#  {'modelId': 'ai4bharat/IndicNER', 'downloads': 507498},
#  {'modelId': 'facebook/hubert-large-ls960-ft', 'downloads': 506227},
#  {'modelId': 'wasmdashai/wasmai-7b-v1', 'downloads': 501262},
#  {'modelId': 'MCG-NJU/videomae-large', 'downloads': 499701},
#  {'modelId': 'finiteautomata/bertweet-base-sentiment-analysis',
#   'downloads': 495871},
#  {'modelId': 'facebook/dinov2-small', 'downloads': 495306},
#  {'modelId': 'ibm-granite/granite-timeseries-ttm-r1', 'downloads': 491887},
#  {'modelId': 'stabilityai/stable-video-diffusion-img2vid-xt',
#   'downloads': 490272},
#  {'modelId': 'distilbert/distilbert-base-multilingual-cased',
#   'downloads': 488748},
#  {'modelId': 'microsoft/layoutlmv2-base-uncased', 'downloads': 487947},
#  {'modelId': 'Lykon/DreamShaper', 'downloads': 487314},
#  {'modelId': 'microsoft/Phi-3.5-mini-instruct', 'downloads': 485762},
#  {'modelId': 'unslothai/vram-48', 'downloads': 480010},
#  {'modelId': 'meta-llama/Llama-3.1-405B', 'downloads': 477725},
#  {'modelId': 'nlpaueb/legal-bert-base-uncased', 'downloads': 474419},
#  {'modelId': 'ybelkada/blip2-opt-2.7b-fp16-sharded', 'downloads': 470636},
#  {'modelId': 'pyannote/voice-activity-detection', 'downloads': 469276},
#  {'modelId': 'google/paligemma-3b-mix-224', 'downloads': 464686},
#  {'modelId': 'intfloat/multilingual-e5-base', 'downloads': 464065},
#  {'modelId': 'diffusers/stable-diffusion-xl-1.0-inpainting-0.1',
#   'downloads': 462723},
#  {'modelId': 'facebook/nllb-200-distilled-600M', 'downloads': 459675},
#  {'modelId': 'NbAiLab/nb-wav2vec2-300m-nynorsk', 'downloads': 456534},
#  {'modelId': 'LanguageBind/LanguageBind_Video_FT', 'downloads': 455873},
#  {'modelId': 'timm/resnet34.a1_in1k', 'downloads': 453960},
#  {'modelId': 'cross-encoder/ms-marco-electra-base', 'downloads': 452397},
#  {'modelId': 'unslothai/vram-80', 'downloads': 452192},
#  {'modelId': 'Helsinki-NLP/opus-mt-nl-en', 'downloads': 446543},
#  {'modelId': 'Helsinki-NLP/opus-mt-de-en', 'downloads': 446072},
#  {'modelId': 'ggml-org/models', 'downloads': 442646},
#  {'modelId': 'google-t5/t5-large', 'downloads': 441086},
#  {'modelId': 'NousResearch/Llama-2-7b-chat-hf', 'downloads': 441064},
#  {'modelId': 'Lykon/AAM_XL_AnimeMix', 'downloads': 441032},
#  {'modelId': 'TheBloke/Mistral-7B-OpenOrca-GPTQ', 'downloads': 440836},
#  {'modelId': 'finiteautomata/bertweet-base-emotion-analysis',
#   'downloads': 439477},
#  {'modelId': 'microsoft/rad-dino', 'downloads': 439244},
#  {'modelId': 'lmsys/vicuna-7b-v1.5', 'downloads': 438191},
#  {'modelId': 'jonatasgrosman/wav2vec2-xls-r-1b-portuguese',
#   'downloads': 437599},
#  {'modelId': 'sentence-transformers/LaBSE', 'downloads': 437001},
#  {'modelId': 'echarlaix/tiny-random-mistral', 'downloads': 434576},
#  {'modelId': 'Sudanl/stable-diffusion-2-1-base-custom', 'downloads': 434549},
#  {'modelId': 'Jean-Baptiste/camembert-ner-with-dates', 'downloads': 433154},
#  {'modelId': 'microsoft/deberta-large-mnli', 'downloads': 431196},
#  {'modelId': 'openart-custom/AlbedoBase', 'downloads': 423790},
#  {'modelId': 'autogluon/tabpfn-mix-1.0-classifier', 'downloads': 422732},
#  {'modelId': 'apple/DFN5B-CLIP-ViT-H-14-378', 'downloads': 421548},
#  {'modelId': 'RunDiffusion/Juggernaut-XL-v6', 'downloads': 420865},
#  {'modelId': 'intfloat/e5-base-v2', 'downloads': 420419},
#  {'modelId': 'hugging-quants/Llama-3.2-1B-Instruct-Q8_0-GGUF',
#   'downloads': 419869},
#  {'modelId': 'furiosa-ai/mlperf-gpt-j-6b', 'downloads': 417811},
#  {'modelId': 'HuggingFaceH4/zephyr-7b-beta', 'downloads': 416712},
#  {'modelId': 'shi-labs/oneformer_ade20k_swin_tiny', 'downloads': 416527},
#  {'modelId': 'nvidia/NV-Embed-v1', 'downloads': 416409},
#  {'modelId': 'h94/IP-Adapter-FaceID', 'downloads': 414989},
#  {'modelId': 'davebulaval/MeaningBERT', 'downloads': 414241},
#  {'modelId': 'sentence-transformers/paraphrase-MiniLM-L3-v2',
#   'downloads': 413408},
#  {'modelId': 'TinyLlama/TinyLlama-1.1B-Chat-v0.6', 'downloads': 412526},
#  {'modelId': 'Helsinki-NLP/opus-mt-ru-en', 'downloads': 410451},
#  {'modelId': 'Snowflake/snowflake-arctic-embed-m', 'downloads': 410046},
#  {'modelId': 'ggrazzioli/cls_sentimento_sebrae', 'downloads': 408187},
#  {'modelId': 'oliverguhr/fullstop-punctuation-multilang-large',
#   'downloads': 405558},
#  {'modelId': 'cecibas/Midnight-Miqu-70B-v1.5-4bit', 'downloads': 403445},
#  {'modelId': 'timm/vgg16.tv_in1k', 'downloads': 402912},
#  {'modelId': 'microsoft/xclip-base-patch32', 'downloads': 402862},
#  {'modelId': 'vikp/surya_order', 'downloads': 402547},
#  {'modelId': 'Leo97/KoELECTRA-small-v3-modu-ner', 'downloads': 402298},
#  {'modelId': 'google/gemma-2b', 'downloads': 400941},
#  {'modelId': 'apple/mobilevit-small', 'downloads': 400284},
#  {'modelId': 'philschmid/bart-large-cnn-samsum', 'downloads': 399448},
#  {'modelId': 'Qwen/Qwen2-VL-7B-Instruct-AWQ', 'downloads': 399373},
#  {'modelId': 'tohoku-nlp/bert-base-japanese-whole-word-masking',
#   'downloads': 397208},
#  {'modelId': 'Systran/faster-whisper-base', 'downloads': 397034},
#  {'modelId': 'google/vivit-b-16x2-kinetics400', 'downloads': 396326},
#  {'modelId': 'fxmarty/really-tiny-falcon-testing', 'downloads': 395590},
#  {'modelId': 'sentence-transformers/msmarco-MiniLM-L6-cos-v5',
#   'downloads': 393685},
#  {'modelId': 'yosuke/bert-base-japanese-char', 'downloads': 391570},
#  {'modelId': 'vikp/surya_layout3', 'downloads': 389772},
#  {'modelId': 'dccuchile/bert-base-spanish-wwm-uncased', 'downloads': 386299},
#  {'modelId': 'Babelscape/wikineural-multilingual-ner', 'downloads': 386152},
#  {'modelId': 'vinai/phobert-base-v2', 'downloads': 385933},
#  {'modelId': 'jondurbin/unstuffer-v0.2', 'downloads': 385213},
#  {'modelId': 'timm/vit_base_patch16_224.augreg2_in21k_ft_in1k',
#   'downloads': 384663},
#  {'modelId': 'distilbert/distilbert-base-cased', 'downloads': 383441},
#  {'modelId': 'tner/roberta-large-ontonotes5', 'downloads': 383162},
#  {'modelId': 'meta-llama/Llama-2-13b-chat-hf', 'downloads': 380926},
#  {'modelId': 'allenai/specter2_aug2023refresh_base', 'downloads': 380837},
#  {'modelId': 'hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4',
#   'downloads': 380579},
#  {'modelId': 'pyannote/brouhaha', 'downloads': 379748},
#  {'modelId': 'facebook/wav2vec2-xlsr-53-espeak-cv-ft', 'downloads': 377063},
#  {'modelId': 'ghunkins/prompt-expansion', 'downloads': 375811},
#  {'modelId': 'meta-llama/Llama-Guard-3-8B', 'downloads': 374919},
#  {'modelId': 'DeepChem/ChemBERTa-77M-MTR', 'downloads': 371189},
#  {'modelId': 'cagliostrolab/animagine-xl-3.1', 'downloads': 370292},
#  {'modelId': 'fxmarty/tiny-random-GemmaForCausalLM', 'downloads': 369915},
#  {'modelId': 'audeering/wav2vec2-large-robust-24-ft-age-gender',
#   'downloads': 369511},
#  {'modelId': 'lucas-leme/FinBERT-PT-BR', 'downloads': 369136},
#  {'modelId': 'yangheng/deberta-v3-base-absa-v1.1', 'downloads': 368259},
#  {'modelId': 'mistralai/Mistral-7B-v0.1', 'downloads': 367718},
#  {'modelId': 'stabilityai/stable-diffusion-2', 'downloads': 366902},
#  {'modelId': 'FacebookAI/roberta-large-mnli', 'downloads': 365434},
#  {'modelId': 'ckiplab/bert-base-chinese-ws', 'downloads': 364841},
#  {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-polish',
#   'downloads': 363773},
#  {'modelId': 'TheBloke/Mistral-7B-Instruct-v0.1-GPTQ', 'downloads': 363487},
#  {'modelId': 'mistralai/Mistral-7B-Instruct-v0.1', 'downloads': 361423},
#  {'modelId': 'XLabs-AI/flux-RealismLora', 'downloads': 359711},
#  {'modelId': 'cointegrated/LaBSE-en-ru', 'downloads': 358934},
#  {'modelId': 'openai/whisper-tiny', 'downloads': 358341},
#  {'modelId': 'TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T',
#   'downloads': 357539},
#  {'modelId': 'microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext',
#   'downloads': 354829},
#  {'modelId': 'DeepFloyd/t5-v1_1-xxl', 'downloads': 354777},
#  {'modelId': 'salmanshahid/vad', 'downloads': 352360},
#  {'modelId': 'salmanshahid/segmentation', 'downloads': 352353},
#  {'modelId': 'flair/ner-french', 'downloads': 352289},
#  {'modelId': 'facebook/esm2_t12_35M_UR50D', 'downloads': 351724},
#  {'modelId': 'Salesforce/blip2-opt-2.7b', 'downloads': 351708},
#  {'modelId': 'google/electra-small-discriminator', 'downloads': 350299},
#  {'modelId': 'nfliu/deberta-v3-large_boolq', 'downloads': 349519},
#  {'modelId': 'unitary/unbiased-toxic-roberta', 'downloads': 347132},
#  {'modelId': 'flair/ner-english', 'downloads': 346682},
#  {'modelId': 'tohoku-nlp/bert-base-japanese-v3', 'downloads': 346412},
#  {'modelId': 'TheBloke/Llama-2-7B-GPTQ', 'downloads': 343967},
#  {'modelId': 'fxmarty/tiny-dummy-qwen2', 'downloads': 343581},
#  {'modelId': 'Xenova/tiny-random-Phi3ForCausalLM', 'downloads': 342658},
#  {'modelId': 'timm/tf_mobilenetv3_large_minimal_100.in1k',
#   'downloads': 342601},
#  {'modelId': 'nvidia/parakeet-tdt-1.1b', 'downloads': 340903},
#  {'modelId': 'rinna/japanese-cloob-vit-b-16', 'downloads': 339838},
#  {'modelId': 'THUDM/glm-4-9b-chat', 'downloads': 338219},
#  {'modelId': 'hustvl/yolos-tiny', 'downloads': 337683},
#  {'modelId': 'neulab/codebert-java', 'downloads': 337535},
#  {'modelId': 'madhurjindal/autonlp-Gibberish-Detector-492513457',
#   'downloads': 334999},
#  {'modelId': 'Orenguteng/Llama-3-8B-Lexi-Uncensored', 'downloads': 334448},
#  {'modelId': 'unsloth/Meta-Llama-3.1-8B-bnb-4bit', 'downloads': 333210},
#  {'modelId': 'openart-custom/DucHaiten-AIart-SDXL_v3', 'downloads': 331540},
#  {'modelId': 'bigcode/starcoder2-3b', 'downloads': 329626},
#  {'modelId': 'sshleifer/tiny-marian-en-de', 'downloads': 329417},
#  {'modelId': 'tencent/DepthCrafter', 'downloads': 328740},
#  {'modelId': 'petals-team/StableBeluga2', 'downloads': 328620},
#  {'modelId': 'facebook/mask2former-swin-large-cityscapes-semantic',
#   'downloads': 325537},
#  {'modelId': 'MoritzLaurer/deberta-v3-base-zeroshot-v1.1-all-33',
#   'downloads': 324331},
#  {'modelId': 'dangvantuan/sentence-camembert-large', 'downloads': 320339},
#  {'modelId': 'openai/whisper-medium.en', 'downloads': 320091},
#  {'modelId': 'emrecan/bert-base-turkish-cased-mean-nli-stsb-tr',
#   'downloads': 319252},
#  {'modelId': 'distil-whisper/distil-large-v3', 'downloads': 318936},
#  {'modelId': 'sonoisa/sentence-bert-base-ja-mean-tokens-v2',
#   'downloads': 318415},
#  {'modelId': 'adrianjoheni/translation-model-opus', 'downloads': 318127},
#  {'modelId': 'jinaai/jina-embeddings-v2-small-en', 'downloads': 318079},
#  {'modelId': 'lewtun/tiny-random-mt5', 'downloads': 317861},
#  {'modelId': 'google/gemma-2-9b-it', 'downloads': 317380},
#  {'modelId': 'stabilityai/stable-diffusion-3-medium-diffusers',
#   'downloads': 316706},
#  {'modelId': 'lllyasviel/sd-controlnet-canny', 'downloads': 316693},
#  {'modelId': 'distilbert/distilbert-base-cased-distilled-squad',
#   'downloads': 315347},
#  {'modelId': 'microsoft/unixcoder-base', 'downloads': 314690},
#  {'modelId': 'sentence-transformers/multi-qa-distilbert-cos-v1',
#   'downloads': 314246},
#  {'modelId': 'fxmarty/pix2struct-tiny-random', 'downloads': 312844},
#  {'modelId': 'botp/stable-diffusion-v1-5', 'downloads': 311969},
#  {'modelId': 'lllyasviel/FLUX.1-dev-gguf', 'downloads': 310419},
#  {'modelId': 'openai-community/gpt2-xl', 'downloads': 309514},
#  {'modelId': 'Systran/faster-whisper-small', 'downloads': 308595},
#  {'modelId': 'BAAI/llm-embedder', 'downloads': 308537},
#  {'modelId': 'deepset/bert-large-uncased-whole-word-masking-squad2',
#   'downloads': 307731},
#  {'modelId': 'solidrust/Codestral-22B-v0.1-hf-AWQ', 'downloads': 307417},
#  {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-persian',
#   'downloads': 307212},
#  {'modelId': 'internlm/internlm-xcomposer2d5-clip', 'downloads': 306737},
#  {'modelId': 'MaziyarPanahi/SmolLM2-360M-Instruct-GGUF', 'downloads': 306569},
#  {'modelId': 'Qwen/Qwen1.5-0.5B', 'downloads': 306245},
#  {'modelId': 'peft-internal-testing/tiny-clip-text-2', 'downloads': 305603},
#  {'modelId': 'facebook/mask2former-swin-large-coco-panoptic',
#   'downloads': 303839},
#  {'modelId': 'textattack/bert-base-uncased-snli', 'downloads': 303675},
#  {'modelId': 'unslothai/aws', 'downloads': 302987},
#  {'modelId': 'facebook/mbart-large-50-many-to-many-mmt', 'downloads': 300229},
#  {'modelId': 'Team-ACE/ToolACE-8B', 'downloads': 299721},
#  {'modelId': 'sentence-transformers/paraphrase-albert-small-v2',
#   'downloads': 297528},
#  {'modelId': 'CompVis/ldm-super-resolution-4x-openimages',
#   'downloads': 294868},
#  {'modelId': 'vectara/hallucination_evaluation_model', 'downloads': 294837},
#  {'modelId': 'microsoft/swinv2-tiny-patch4-window16-256', 'downloads': 293592},
#  {'modelId': 'Alibaba-NLP/gte-base-en-v1.5', 'downloads': 292751},
#  {'modelId': 'llamafactory/tiny-random-Llama-3', 'downloads': 291461},
#  {'modelId': 'Systran/faster-whisper-tiny', 'downloads': 289331},
#  {'modelId': 'shahrukhx01/bert-mini-finetune-question-detection',
#   'downloads': 286625},
#  {'modelId': 'neuralmagic/Meta-Llama-3.1-8B-Instruct-FP8',
#   'downloads': 286420},
#  {'modelId': 'autogluon/chronos-t5-base', 'downloads': 285914},
#  {'modelId': 'facebook/sam-vit-large', 'downloads': 283735},
#  {'modelId': 'aipicasso/emi', 'downloads': 283581},
#  {'modelId': 'Helsinki-NLP/opus-mt-en-ar', 'downloads': 283256},
#  {'modelId': 'eenzeenee/t5-base-korean-summarization', 'downloads': 283073},
#  {'modelId': 'timm/vit_base_patch16_384.augreg_in21k_ft_in1k',
#   'downloads': 281796},
#  {'modelId': 'openai/whisper-small.en', 'downloads': 281686},
#  {'modelId': 'moka-ai/m3e-base', 'downloads': 281510},
#  {'modelId': 'neulab/codebert-python', 'downloads': 281092},
#  {'modelId': 'aglazkova/bart_finetuned_keyphrase_extraction',
#   'downloads': 279771},
#  {'modelId': 'datificate/gpt2-small-spanish', 'downloads': 277677},
#  {'modelId': 'Salesforce/codet5p-110m-embedding', 'downloads': 277666},
#  {'modelId': 'monologg/kobert', 'downloads': 275635},
#  {'modelId': 'h2oai/h2ogpt-4096-llama2-7b-chat', 'downloads': 275267},
#  {'modelId': 'intfloat/multilingual-e5-large-instruct', 'downloads': 274603},
#  {'modelId': 'EleutherAI/gpt-neo-2.7B', 'downloads': 274204},
#  {'modelId': 'google/siglip-base-patch16-224', 'downloads': 274035},
#  {'modelId': 'neuralmind/bert-large-portuguese-cased', 'downloads': 273921},
#  {'modelId': 'microsoft/DialoGPT-medium', 'downloads': 273758},
#  {'modelId': 'speechbrain/lang-id-voxlingua107-ecapa', 'downloads': 269833},
#  {'modelId': 'Salesforce/blip2-opt-6.7b-coco', 'downloads': 269800},
#  {'modelId': 'Salesforce/instructblip-vicuna-7b', 'downloads': 269239},
#  {'modelId': 'hkunlp/instructor-large', 'downloads': 269157},
#  {'modelId': 'mrm8488/bert-tiny-finetuned-sms-spam-detection',
#   'downloads': 268883},
#  {'modelId': 'microsoft/xclip-large-patch14', 'downloads': 267944},
#  {'modelId': 'Salesforce/blip-vqa-base', 'downloads': 265534},
#  {'modelId': 'to-be/donut-base-finetuned-invoices', 'downloads': 263577},
#  {'modelId': 'google/vit-large-patch32-384', 'downloads': 263451},
#  {'modelId': 'neuralmagic/Llama-3.2-1B-Instruct-FP8', 'downloads': 262596},
#  {'modelId': 'dslim/bert-large-NER', 'downloads': 262353},
#  {'modelId': 'malteos/scincl', 'downloads': 261428},
#  {'modelId': 'monologg/koelectra-small-v2-distilled-korquad-384',
#   'downloads': 261357},
#  {'modelId': 'cross-encoder/nli-deberta-v3-base', 'downloads': 261012},
#  {'modelId': 'unslothai/colab', 'downloads': 260920},
#  {'modelId': 'doc2query/msmarco-t5-base-v1', 'downloads': 258529},
#  {'modelId': 'Qwen/Qwen1.5-1.8B', 'downloads': 256653},
#  {'modelId': 'facebook/dino-vitb16', 'downloads': 256544},
#  {'modelId': 'cross-encoder/ms-marco-MiniLM-L-2-v2', 'downloads': 255465},
#  {'modelId': 'sentence-transformers/msmarco-distilbert-cos-v5',
#   'downloads': 254584},
#  {'modelId': 'timm/vit_base_patch16_224.augreg_in21k', 'downloads': 254503},
#  {'modelId': 'basel/ATTACK-BERT', 'downloads': 253606},
#  {'modelId': 'timm/vit_base_patch16_clip_224.openai', 'downloads': 253530},
#  {'modelId': 'oliverguhr/german-sentiment-bert', 'downloads': 252551},
#  {'modelId': 'crynux-ai/stable-diffusion-v1-5', 'downloads': 252110},
#  {'modelId': 'DeepPavlov/rubert-base-cased', 'downloads': 250692},
#  {'modelId': 'Qwen/Qwen2.5-72B-Instruct', 'downloads': 250239},
#  {'modelId': 'vikp/texify', 'downloads': 250119},
#  {'modelId': 'liuhaotian/llava-v1.5-13b', 'downloads': 248028},
#  {'modelId': 'TahaDouaji/detr-doc-table-detection', 'downloads': 247620},
#  {'modelId': 'EleutherAI/pythia-14m', 'downloads': 247303},
#  {'modelId': 'DeepChem/ChemBERTa-77M-MLM', 'downloads': 247112},
#  {'modelId': 'YxZhang/evf-sam2-multitask', 'downloads': 247078},
#  {'modelId': 'Intel/dpt-hybrid-midas', 'downloads': 245627},
#  {'modelId': 'autogluon/chronos-bolt-mini', 'downloads': 245514},
#  {'modelId': 'JackFram/llama-160m', 'downloads': 245178},
#  {'modelId': 'facebook/w2v-bert-2.0', 'downloads': 244348},
#  {'modelId': 'sentence-transformers/clip-ViT-B-32-multilingual-v1',
#   'downloads': 241838},
#  {'modelId': 'vikhyatk/moondream2', 'downloads': 241838},
#  {'modelId': 'facebook/opt-350m', 'downloads': 241010},
#  {'modelId': 'fxmarty/tiny-doc-qa-vision-encoder-decoder',
#   'downloads': 240163},
#  {'modelId': 'laion/CLIP-convnext_large_d_320.laion2B-s29B-b131K-ft-soup',
#   'downloads': 240146},
#  {'modelId': 'facebook/dpr-ctx_encoder-single-nq-base', 'downloads': 238837},
#  {'modelId': 'google/t5-v1_1-base', 'downloads': 238238},
#  {'modelId': 'AutonLab/MOMENT-1-large', 'downloads': 237966},
#  {'modelId': 'EleutherAI/gpt-j-6b', 'downloads': 237241},
#  {'modelId': 'VAGOsolutions/Llama-3.1-SauerkrautLM-8b-Instruct',
#   'downloads': 236875},
# ...
#  {'modelId': 'zer0int/CLIP-GmP-ViT-L-14', 'downloads': 188150},
#  {'modelId': 'sentence-transformers/paraphrase-TinyBERT-L6-v2',
#   'downloads': 187815},
#  {'modelId': 'reazon-research/reazonspeech-nemo-v2', 'downloads': 187279},
#  {'modelId': 'stabilityai/sdxl-vae', 'downloads': 186906},
#  {'modelId': 'MoritzLaurer/mDeBERTa-v3-base-mnli-xnli', 'downloads': 186254},
#  {'modelId': 'microsoft/wavlm-large', 'downloads': 185975},
#  {'modelId': 'Qwen/Qwen2.5-Coder-32B-Instruct', 'downloads': 185059},
#  {'modelId': 'microsoft/wavlm-base-plus-sv', 'downloads': 184940},
#  {'modelId': 'furiosa-ai/mlperf-bert-large', 'downloads': 184759},
#  {'modelId': 'Gustavosta/MagicPrompt-Stable-Diffusion', 'downloads': 184170},
#  {'modelId': 'Qwen/Qwen2.5-1.5B', 'downloads': 184136},
#  {'modelId': 'google/metricx-23-large-v2p0', 'downloads': 183970},
#  {'modelId': 'microsoft/codebert-base-mlm', 'downloads': 183314},
#  {'modelId': 'microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224',
#   'downloads': 182571},
#  {'modelId': 'cross-encoder/nli-deberta-base', 'downloads': 182567},
#  {'modelId': 'google/metricx-23-qe-large-v2p0', 'downloads': 181924},
#  {'modelId': 'dbmdz/bert-base-turkish-cased', 'downloads': 181408},
#  {'modelId': 'google/electra-small-generator', 'downloads': 181337},
#  {'modelId': 'katuni4ka/tiny-random-baichuan2-13b', 'downloads': 181282},
#  {'modelId': 'mistralai/Mistral-Nemo-Instruct-2407', 'downloads': 180938},
#  {'modelId': 'google/siglip-large-patch16-384', 'downloads': 180891},
#  {'modelId': 'vinai/phobert-base', 'downloads': 179850},
#  {'modelId': 'katuni4ka/tiny-random-jais', 'downloads': 179678},
#  {'modelId': 'intfloat/e5-mistral-7b-instruct', 'downloads': 179258},
#  {'modelId': 'optimum-internal-testing/tiny-random-llama',
#   'downloads': 178811},
#  {'modelId': 'bofenghuang/whisper-large-v3-french', 'downloads': 178798},
#  {'modelId': 'flair/ner-english-ontonotes', 'downloads': 178308},
#  {'modelId': 'timm/convnext_xxlarge.clip_laion2b_soup_ft_in1k',
#   'downloads': 177763},
#  {'modelId': 'nvidia/bigvgan_v2_22khz_80band_256x', 'downloads': 176994},
#  {'modelId': 'codesage/codesage-large', 'downloads': 176761},
#  {'modelId': 'nvidia/Llama-3.1-Nemotron-70B-Instruct-HF', 'downloads': 176401},
#  {'modelId': 'neuralmagic/Llama-3.2-11B-Vision-Instruct-FP8-dynamic',
#   'downloads': 176217},
#  {'modelId': 'UFNLP/gatortron-base', 'downloads': 175583},
#  {'modelId': 'latent-consistency/lcm-lora-sdv1-5', 'downloads': 175453},
#  {'modelId': 'microsoft/Florence-2-base', 'downloads': 175175},
#  {'modelId': 'ByteDance/Hyper-SD', 'downloads': 174954},
#  {'modelId': 'Efficient-Large-Model/Llama-3-VILA1.5-8B-Fix',
#   'downloads': 174139},
#  {'modelId': 'autogluon/chronos-bolt-base', 'downloads': 173159},
#  {'modelId': 'fxmarty/tiny-llama-fast-tokenizer', 'downloads': 172875},
#  {'modelId': 'flair/ner-german-large', 'downloads': 172763},
#  {'modelId': 'jukofyork/creative-writing-control-vectors-v3.0',
#   'downloads': 172501},
#  {'modelId': 'timpal0l/mdeberta-v3-base-squad2', 'downloads': 171856},
#  {'modelId': 'SG161222/Realistic_Vision_V2.0', 'downloads': 171841},
#  {'modelId': 'crynux-ai/sdxl-turbo', 'downloads': 171830},
#  {'modelId': 'vikp/surya_tablerec', 'downloads': 171744},
#  {'modelId': 'sentence-transformers/msmarco-bert-base-dot-v5',
#   'downloads': 171081},
#  {'modelId': 'microsoft/trocr-large-printed', 'downloads': 171052},
#  {'modelId': 'timm/tf_mobilenetv3_small_minimal_100.in1k',
#   'downloads': 170978},
#  {'modelId': 'Intel/dpt-large', 'downloads': 170935},
#  {'modelId': 'nguyenvulebinh/wav2vec2-base-vi', 'downloads': 170928},
#  {'modelId': 'Systran/faster-whisper-small.en', 'downloads': 170779},
#  {'modelId': 'aspire/acge_text_embedding', 'downloads': 170692},
#  {'modelId': 'modularai/replit-code-1.5', 'downloads': 170399},
#  {'modelId': 'Qwen/Qwen2.5-Coder-7B-Instruct', 'downloads': 170382},
#  {'modelId': 'facebook/opt-6.7b', 'downloads': 170269},
#  {'modelId': 'unslothai/kaggle', 'downloads': 170042},
#  {'modelId': 'flair/pos-english', 'downloads': 169865},
#  {'modelId': 'solidrust/Mistral-7B-Instruct-v0.3-AWQ', 'downloads': 169816},
#  {'modelId': 'timm/vit_base_r50_s16_384.orig_in21k_ft_in1k',
#   'downloads': 169647},
#  {'modelId': 'stabilityai/stable-diffusion-2-depth', 'downloads': 169546},
#  {'modelId': 'Hate-speech-CNERG/dehatebert-mono-portugese',
#   'downloads': 168724},
#  {'modelId': 'timbrooks/instruct-pix2pix', 'downloads': 168380},
#  {'modelId': 'joeddav/xlm-roberta-large-xnli', 'downloads': 168197},
#  {'modelId': 'Yehor/w2v-xls-r-uk', 'downloads': 168138},
#  {'modelId': 'meta-llama/Llama-3.1-405B-Instruct', 'downloads': 166954},
#  {'modelId': 'SenswiseData/bert_cased_ner', 'downloads': 166034},
#  {'modelId': 'ByteDance/SDXL-Lightning', 'downloads': 165634},
#  {'modelId': 'mixedbread-ai/mxbai-rerank-base-v1', 'downloads': 164828},
#  {'modelId': 'Qwen/Qwen2-1.5B-Instruct', 'downloads': 164713},
#  {'modelId': 'MaziyarPanahi/calme-3.1-baguette-3b-GGUF', 'downloads': 164696},
#  {'modelId': 'Helsinki-NLP/opus-mt-it-en', 'downloads': 164414},
#  {'modelId': 'THUDM/cogvlm2-llama3-chat-19B', 'downloads': 164123},
#  {'modelId': 'laion/clap-htsat-unfused', 'downloads': 163901},
#  {'modelId': 'bookbot/wav2vec2-ljspeech-gruut', 'downloads': 163590},
#  {'modelId': 'LanguageBind/LanguageBind_Audio_FT', 'downloads': 163568},
#  {'modelId': 'jonatasgrosman/wav2vec2-large-xlsr-53-hungarian',
#   'downloads': 163470},
#  {'modelId': 'echarlaix/tiny-random-PhiForCausalLM', 'downloads': 163104},
#  {'modelId': 'SanctumAI/Meta-Llama-3.1-8B-Instruct-GGUF', 'downloads': 163101},
#  {'modelId': 'flair/upos-english', 'downloads': 162893},
#  {'modelId': 'Systran/faster-distil-whisper-medium.en', 'downloads': 162465},
#  {'modelId': 'Qwen/Qwen1.5-7B', 'downloads': 162423},
#  {'modelId': 'openlm-research/open_llama_3b', 'downloads': 162330},
#  {'modelId': 'numind/NuNER_Zero', 'downloads': 162144},
#  {'modelId': 'nvidia/bigvgan_v2_44khz_128band_512x', 'downloads': 161920},
#  {'modelId': 'mixedbread-ai/mxbai-rerank-xsmall-v1', 'downloads': 161709},
#  {'modelId': 'Helsinki-NLP/opus-mt-en-de', 'downloads': 160792},
#  {'modelId': 'huawei-noah/TinyBERT_General_4L_312D', 'downloads': 160743},
#  {'modelId': 'NousResearch/Meta-Llama-3-8B-Instruct', 'downloads': 160742},
#  {'modelId': 'dicta-il/dictalm2.0-instruct', 'downloads': 158830},
#  {'modelId': 'cambridgeltl/SapBERT-from-PubMedBERT-fulltext-mean-token',
#   'downloads': 158639},
#  {'modelId': 'monologg/koelectra-base-v3-goemotions', 'downloads': 158601},
#  {'modelId': 'SG161222/Realistic_Vision_V5.1_noVAE', 'downloads': 158234},
#  {'modelId': 'vikhyatk/moondream1', 'downloads': 157432},
#  {'modelId': 'SenswiseData/bert_turkish_sentiment', 'downloads': 157340},
#  {'modelId': 'pysentimiento/bertweet-pt-sentiment', 'downloads': 157117},
#  {'modelId': 'Qwen/Qwen2-0.5B-Instruct', 'downloads': 156998},
#  {'modelId': 'facebook/bart-large', 'downloads': 156646},
#  {'modelId': 'distilbert/distilbert-base-uncased-distilled-squad',
#   'downloads': 156297},
#  {'modelId': 'timm/mobilenetv3_large_100.miil_in21k_ft_in1k',
#   'downloads': 155554},
#  {'modelId': 'cahya/bert-base-indonesian-NER', 'downloads': 154399},
#  {'modelId': 'google/pegasus-xsum', 'downloads': 154346},
#  {'modelId': 'mohitsha/tiny-random-testing-bert2gpt2', 'downloads': 153187},
#  {'modelId': 'microsoft/trocr-small-printed', 'downloads': 151077},
#  {'modelId': 'fal-collab-models/dreamshaper-xl-1-0', 'downloads': 150832},
#  {'modelId': 'facebook/dpr-question_encoder-multiset-base',
#   'downloads': 149965},
#  {'modelId': 'google/pix2struct-large', 'downloads': 149133},
#  {'modelId': 'cointegrated/rubert-base-cased-nli-threeway',
#   'downloads': 148650},
#  {'modelId': 'jordiclive/flan-t5-3b-summarizer', 'downloads': 148484},
#  {'modelId': 'microsoft/DialoGPT-large', 'downloads': 148480},
#  {'modelId': 'kingabzpro/wav2vec2-large-xls-r-300m-Urdu', 'downloads': 148375},
#  {'modelId': 'NeuML/pubmedbert-base-embeddings', 'downloads': 148286},
#  {'modelId': 'artificialguybr/ColoringBookRedmond-V2', 'downloads': 148245},
#  {'modelId': 'ufal/robeczech-base', 'downloads': 148161},
#  {'modelId': 'unslothai/gcp', 'downloads': 147670},
#  {'modelId': 'bhadresh-savani/distilbert-base-uncased-emotion',
#   'downloads': 146409},
#  {'modelId': 'meta-llama/Llama-2-70b-chat-hf', 'downloads': 145815},
#  {'modelId': 'kykim/bert-kor-base', 'downloads': 145688},
#  {'modelId': 'microsoft/kosmos-2-patch14-224', 'downloads': 145607},
#  {'modelId': 'HuggingFaceM4/tiny-random-LlamaForCausalLM',
#   'downloads': 145483},
#  {'modelId': 'depth-anything/Depth-Anything-V2-Large-hf', 'downloads': 145225},
#  {'modelId': 'google/tapas-large-finetuned-wtq', 'downloads': 145057},
#  {'modelId': 'prithivida/parrot_adequacy_model', 'downloads': 145023},
#  {'modelId': 'wangqixun/YamerMIX_v8', 'downloads': 144836},
#  {'modelId': 'autogluon/chronos-t5-small', 'downloads': 143995},
#  {'modelId': 'microsoft/Phi-3-vision-128k-instruct', 'downloads': 143517},
#  {'modelId': 'sentinet/suicidality', 'downloads': 143462},
#  {'modelId': 'ali-vilab/In-Context-LoRA', 'downloads': 143262},
#  {'modelId': 'tiiuae/falcon-40b', 'downloads': 142964},
#  {'modelId': 'fixie-ai/ultravox-v0_3', 'downloads': 142797},
#  {'modelId': 'katuni4ka/tiny-random-qwen', 'downloads': 142493},
#  {'modelId': 'argmaxinc/whisperkit-coreml', 'downloads': 142170},
#  {'modelId': 'timm/vit_large_patch14_dinov2.lvd142m', 'downloads': 141571},
#  {'modelId': 'Ericwang/tiny-random-ast', 'downloads': 141117},
#  {'modelId': 'Marqo/marqo-fashionSigLIP', 'downloads': 140640},
#  {'modelId': 'google/vit-base-patch16-384', 'downloads': 140129},
#  {'modelId': 'Dmyadav2001/Sentimental-Analysis', 'downloads': 140027},
#  {'modelId': 'katuni4ka/tiny-random-orion', 'downloads': 139954},
#  {'modelId': 'NlpHUST/ner-vietnamese-electra-base', 'downloads': 139850},
#  {'modelId': 'bespin-global/klue-sroberta-base-continue-learning-by-mnr',
#   'downloads': 139731},
#  {'modelId': 'sentence-transformers/msmarco-MiniLM-L12-cos-v5',
#   'downloads': 139565},
#  {'modelId': 'katuni4ka/tiny-random-decilm', 'downloads': 139233},
#  {'modelId': 'nvidia/parakeet-tdt_ctc-0.6b-ja', 'downloads': 139017},
#  {'modelId': 'openai-community/roberta-large-openai-detector',
#   'downloads': 138713},
#  {'modelId': 'timm/inception_resnet_v2.tf_in1k', 'downloads': 138531},
#  {'modelId': 'prajjwal1/bert-mini', 'downloads': 138512},
#  {'modelId': 'EleutherAI/pythia-70m', 'downloads': 138438},
#  {'modelId': 'EleutherAI/gpt-neo-125m', 'downloads': 138176},
#  {'modelId': 'echarlaix/tiny-random-stable-diffusion-xl', 'downloads': 137482},
#  {'modelId': 'obh07/multilingual-e5-base-dolly-15k', 'downloads': 137337},
#  {'modelId': 'dmis-lab/biobert-base-cased-v1.1', 'downloads': 137123},
#  {'modelId': 'THUDM/CogVideoX-5b', 'downloads': 137123},
#  {'modelId': 'pdelobelle/robbert-v2-dutch-ner', 'downloads': 136547},
#  {'modelId': 'nvidia/Llama-3_1-Nemotron-51B-Instruct', 'downloads': 136543},
#  {'modelId': 'davidkim205/ko-gemma-2-9b-it', 'downloads': 136289},
#  {'modelId': 'BAAI/bge-multilingual-gemma2', 'downloads': 136269},
#  {'modelId': 'microsoft/speecht5_tts', 'downloads': 135687},
#  {'modelId': 'timm/vit_small_patch16_224.augreg_in21k_ft_in1k',
#   'downloads': 135210},
#  {'modelId': 'pparasurama/raceBERT-ethnicity', 'downloads': 134603},
#  {'modelId': 'katuni4ka/tiny-random-falcon-40b', 'downloads': 134050},
#  {'modelId': 'tasksource/deberta-small-long-nli', 'downloads': 133925},
#  {'modelId': 'microsoft/speecht5_hifigan', 'downloads': 133910},
#  {'modelId': 'OpenGVLab/InternVL2-8B', 'downloads': 133632},
#  {'modelId': 'TheBloke/Mistral-7B-Instruct-v0.2-GGUF', 'downloads': 133125},
#  {'modelId': 'tuner007/pegasus_paraphrase', 'downloads': 133046},
#  {'modelId': 'optimum-internal-testing/tiny-random-whisper',
#   'downloads': 132795},
#  {'modelId': 'mistralai/Mixtral-8x22B-Instruct-v0.1', 'downloads': 132585},
#  {'modelId': 'SWivid/E2-TTS', 'downloads': 132573},
#  {'modelId': 'hiiamsid/sentence_similarity_spanish_es', 'downloads': 132114},
#  {'modelId': 'tohoku-nlp/bert-base-japanese-char-v2', 'downloads': 131863},
#  {'modelId': 'MaziyarPanahi/Meraj-Mini-GGUF', 'downloads': 131216},
#  {'modelId': 'michaelfeil/bge-small-en-v1.5', 'downloads': 130814},
#  {'modelId': 'Helsinki-NLP/opus-mt-en-it', 'downloads': 130811},
#  {'modelId': 'kuleshov-group/caduceus-ps_seqlen-131k_d_model-256_n_layer-16',
#   'downloads': 130776},
#  {'modelId': 'MaziyarPanahi/Meta-Llama-3-70B-Instruct-GGUF',
#   'downloads': 130742},
#  {'modelId': 'microsoft/graphcodebert-base', 'downloads': 130689},
#  {'modelId': 'dataautogpt3/ProteusV0.3', 'downloads': 130676},
#  {'modelId': 'OpenGVLab/InternVL2-Llama3-76B', 'downloads': 130673},
#  {'modelId': 'Snowflake/snowflake-arctic-embed-xs', 'downloads': 130039},
#  {'modelId': 'MaziyarPanahi/Mistral-Large-Instruct-2407-GGUF',
#   'downloads': 129971},
#  {'modelId': 'ckiplab/bert-base-chinese-pos', 'downloads': 129565},
#  {'modelId': 'ehcalabres/wav2vec2-lg-xlsr-en-speech-emotion-recognition',
#   'downloads': 129504},
#  {'modelId': 'jtlicardo/bpmn-information-extraction-v2', 'downloads': 129465},
#  {'modelId': 'depth-anything/Depth-Anything-V2-Small-hf', 'downloads': 129319},
#  {'modelId': 'sentence-transformers/sentence-t5-xl', 'downloads': 129211},
#  {'modelId': 'ml6team/keyphrase-extraction-distilbert-inspec',
#   'downloads': 128873},
#  {'modelId': 'Michau/t5-base-en-generate-headline', 'downloads': 128373},
#  {'modelId': 'facebook/mask2former-swin-tiny-coco-instance',
#   'downloads': 128330},
#  {'modelId': 'InstantX/InstantID', 'downloads': 128248},
#  {'modelId': 'timm/vit_base_patch8_224.augreg2_in21k_ft_in1k',
#   'downloads': 128191},
#  {'modelId': 'YxZhang/evf-sam2', 'downloads': 127403},
#  {'modelId': 'google-bert/bert-large-uncased-whole-word-masking-finetuned-squad',
#   'downloads': 126786},
#  {'modelId': 'stabilityai/stable-diffusion-3.5-medium', 'downloads': 125900},
#  {'modelId': 'unslothai/vram-8', 'downloads': 125813},
#  {'modelId': 'Qwen/Qwen2-VL-72B-Instruct-GPTQ-Int4', 'downloads': 125810},
#  {'modelId': 'anton-l/wav2vec2-random-tiny-classifier', 'downloads': 125289},
#  {'modelId': 'sanchit-gandhi/whisper-medium-fleurs-lang-id',
#   'downloads': 125031},
#  {'modelId': 'vikp/surya_det2', 'downloads': 124664},
#  {'modelId': 'city96/FLUX.1-dev-gguf', 'downloads': 124266},
#  {'modelId': 'google/mt5-small', 'downloads': 124222},
#  {'modelId': 'audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim',
#   'downloads': 123951},
#  {'modelId': 'MRNH/mbart-english-grammar-corrector', 'downloads': 123844},
#  {'modelId': 'katuni4ka/tiny-random-chatglm2', 'downloads': 123704},
#  {'modelId': 'ailegends/xlsr-jonatasgrosman-wav2vec2-large-xlsr-53-english',
#   'downloads': 123548},
#  {'modelId': 'hpcai-tech/OpenSora-STDiT-v3', 'downloads': 123500},
#  {'modelId': 'tohoku-nlp/bert-base-japanese-char', 'downloads': 123354},
#  {'modelId': 'llava-hf/LLaVA-NeXT-Video-7B-hf', 'downloads': 123301},
#  {'modelId': 'pierreguillou/ner-bert-base-cased-pt-lenerbr',
#   'downloads': 123184},
#  {'modelId': 'HooshvareLab/bert-fa-base-uncased-ner-peyma',
#   'downloads': 122993},
#  {'modelId': 'katuni4ka/tiny-random-glm4', 'downloads': 122686},
#  {'modelId': 'openai/whisper-large', 'downloads': 122520},
#  {'modelId': 'hugging-quants/Meta-Llama-3.1-405B-Instruct-AWQ-INT4',
#   'downloads': 122398},
#  {'modelId': 'unsloth/Llama-3.2-11B-Vision-Instruct-bnb-4bit',
#   'downloads': 122233},
#  {'modelId': 's-nlp/roberta_toxicity_classifier', 'downloads': 121877},
#  {'modelId': 'facebook/mms-1b-all', 'downloads': 121868},
#  {'modelId': 'katuni4ka/tiny-random-codegen2', 'downloads': 121767},
#  {'modelId': 'naver/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric',
#   'downloads': 121339},
#  {'modelId': 'koheiduck/bert-japanese-finetuned-sentiment',
#   'downloads': 121029},
#  {'modelId': 'allenai/OLMo-1B-0724-hf', 'downloads': 120767},
#  {'modelId': 'tiiuae/falcon-7b', 'downloads': 120491},
#  {'modelId': 'dmis-lab/biobert-base-cased-v1.2', 'downloads': 120413},
#  {'modelId': 'microsoft/phi-1_5', 'downloads': 120190},
#  {'modelId': 'meta-llama/Llama-3.2-11B-Vision', 'downloads': 119993},
#  {'modelId': 'google/mobilebert-uncased', 'downloads': 119975},
#  {'modelId': 'unslothai/colabpro', 'downloads': 119903}]

# %%
model_data = [
    {
        "modelId": model["modelId"],
        "downloads": model["downloads"],
        "organization": model["modelId"].split("/")[0] if "/" in model["modelId"] else "unknown"
    }
    for model in models
]

# Convert to DataFrame for easier grouping
df = pd.DataFrame(model_data)
print(len(df["organization"].unique()))

# Group by organization and keep the model with the most downloads
top_models = df.loc[df.groupby("organization")["downloads"].idxmax()]
# Out:
# 363

# %%
len(top_models)
top_models.to_csv('models_info.csv', index = False)

# %%
models_id = top_models["modelId"].tolist()
models_id
# Out:
# ['1-800-BAD-CODE/punctuation_fullstop_truecase_english',
#  'AdamCodd/vit-base-nsfw-detector',
#  'Alibaba-NLP/gte-large-en-v1.5',
#  'Ashishkr/query_wellformedness_score',
#  'AutonLab/MOMENT-1-large',
#  'BAAI/bge-small-en-v1.5',
#  'Babelscape/wikineural-multilingual-ner',
#  'BridgeTower/bridgetower-large-itm-mlm-itc',
#  'ByteDance/Hyper-SD',
#  'CIDAS/clipseg-rd64-refined',
#  'Cloudy1225/stackoverflow-roberta-base-sentiment',
#  'CompVis/stable-diffusion-safety-checker',
#  'Danswer/intent-model',
#  'DeepChem/ChemBERTa-77M-MTR',
#  'DeepFloyd/t5-v1_1-xxl',
#  'DeepPavlov/rubert-base-cased',
#  'Dmyadav2001/Sentimental-Analysis',
#  'Efficient-Large-Model/Llama-3-VILA1.5-8B-Fix',
#  'EleutherAI/gpt-neo-2.7B',
#  'EmergentMethods/gliner_medium_news-v2.1',
#  'Ericwang/tiny-random-ast',
#  'FacebookAI/xlm-roberta-large',
#  'Falconsai/nsfw_image_detection',
#  'Gustavosta/MagicPrompt-Stable-Diffusion',
#  'Hate-speech-CNERG/tamil-codemixed-abusive-MuRIL',
#  'Helsinki-NLP/opus-mt-fr-en',
#  'HooshvareLab/bert-fa-base-uncased-ner-peyma',
#  'HuggingFaceH4/zephyr-7b-beta',
#  'HuggingFaceM4/siglip-so400m-14-384',
#  'IDEA-Research/grounding-dino-tiny',
#  'InstantX/InstantID',
#  'Intel/dpt-hybrid-midas',
#  'Isotr0py/test-gguf-sample',
#  'JackFram/llama-68m',
#  'Jean-Baptiste/camembert-ner-with-dates',
#  'LTP/small',
#  'Lajavaness/bilingual-embedding-large',
#  'LanguageBind/LanguageBind_Video_FT',
#  'Leo97/KoELECTRA-small-v3-modu-ner',
#  'LiheYoung/depth-anything-large-hf',
#  'Lykon/DreamShaper',
#  'M-CLIP/XLM-Roberta-Large-Vit-B-32',
#  'MCG-NJU/videomae-large',
#  'MIT/ast-finetuned-audioset-10-10-0.4593',
#  'MMG/xlm-roberta-large-ner-spanish',
#  'MRNH/mbart-english-grammar-corrector',
#  'MahmoudAshraf/mms-300m-1130-forced-aligner',
#  'Marqo/marqo-fashionSigLIP',
#  'MattyB95/AST-VoxCelebSpoof-Synthetic-Voice-Detection',
#  'Maykeye/TinyLLama-v0',
#  'MaziyarPanahi/Mistral-7B-Instruct-v0.3-GGUF',
#  'Michau/t5-base-en-generate-headline',
#  'Minej/bert-base-personality',
#  'Moritz-Pfeifer/CentralBankRoBERTa-sentiment-classifier',
#  'MoritzLaurer/DeBERTa-v3-base-mnli-fever-anli',
#  'NbAiLab/nb-wav2vec2-300m-nynorsk',
#  'NeuML/pubmedbert-base-embeddings',
#  'NlpHUST/ner-vietnamese-electra-base',
#  'NousResearch/Llama-2-7b-chat-hf',
#  'OpenAssistant/oasst-sft-4-pythia-12b-epoch-3.5',
#  'OpenGVLab/InternVL2-8B',
#  'Orenguteng/Llama-3-8B-Lexi-Uncensored',
#  'ProsusAI/finbert',
#  'Qdrant/all-MiniLM-L6-v2-onnx',
#  'Qwen/Qwen2.5-1.5B-Instruct',
#  'RishuD7/CML_Text_date_number_blank_v1',
#  'Rostlab/prot_bert',
#  'RunDiffusion/Juggernaut-XL-v9',
#  'SG161222/RealVisXL_V4.0',
#  'SWivid/F5-TTS',
#  'Salesforce/blip-image-captioning-large',
#  'SamLowe/roberta-base-go_emotions',
#  'SanctumAI/Meta-Llama-3.1-8B-Instruct-GGUF',
#  'SenswiseData/bert_cased_ner',
#  'Shakker-Labs/FLUX.1-dev-LoRA-AntiBlur',
#  'Snowflake/snowflake-arctic-embed-m',
#  'SpanBERT/spanbert-large-cased',
#  'Sudanl/stable-diffusion-2-1-base-custom',
#  'Supabase/gte-small',
#  'Systran/faster-whisper-large-v3',
#  'T-Systems-onsite/cross-en-de-roberta-sentence-transformer',
#  'THUDM/chatglm2-6b',
#  'TahaDouaji/detr-doc-table-detection',
#  'TaylorAI/bge-micro-v2',
#  'Team-ACE/ToolACE-8B',
#  'TheBloke/Mistral-7B-Instruct-v0.2-GPTQ',
#  'TinyLlama/TinyLlama-1.1B-Chat-v1.0',
#  'Tochka-AI/ruRoPEBert-e5-base-2k',
#  'UFNLP/gatortron-base',
#  'VAGOsolutions/Llama-3.1-SauerkrautLM-8b-Instruct',
#  'WhereIsAI/UAE-Large-V1',
#  'WinKawaks/vit-tiny-patch16-224',
#  'XLabs-AI/flux-RealismLora',
#  'Xenova/bge-base-en-v1.5',
#  'Yehor/w2v-xls-r-uk',
#  'YituTech/conv-bert-base',
#  'YxZhang/evf-sam2-multitask',
#  'ZhengPeng7/BiRefNet',
#  'adrianjoheni/translation-model-opus',
#  'adsabs/astroBERT',
#  'aglazkova/bart_finetuned_keyphrase_extraction',
#  'ai-forever/sbert_large_nlu_ru',
#  'ai4bharat/indic-bert',
#  'ailegends/xlsr-jonatasgrosman-wav2vec2-large-xlsr-53-english',
#  'aipicasso/emi',
#  'albert/albert-base-v2',
#  'alefiury/wav2vec2-large-xlsr-53-gender-recognition-librispeech',
#  'ali-vilab/In-Context-LoRA',
#  'allenai/longformer-base-4096',
#  'almanach/camembert-base',
#  'amazon/chronos-t5-small',
#  'amunchet/rorshark-vit-base',
#  'answerdotai/answerai-colbert-small-v1',
#  'anton-l/wav2vec2-random-tiny-classifier',
#  'apple/OpenELM-1_1B-Instruct',
#  'argmaxinc/whisperkit-coreml',
#  'artificialguybr/ColoringBookRedmond-V2',
#  'ashawkey/mvdream-sd2.1-diffusers',
#  'aspire/acge_text_embedding',
#  'aubmindlab/bert-base-arabertv02',
#  'audeering/wav2vec2-large-robust-24-ft-age-gender',
#  'autogluon/chronos-t5-tiny',
#  'avsolatorio/GIST-small-Embedding-v0',
#  'bartowski/Meta-Llama-3.1-8B-Instruct-GGUF',
#  'basel/ATTACK-BERT',
#  'benjamin/wtp-canine-s-1l',
#  'bespin-global/klue-sroberta-base-continue-learning-by-mnr',
#  'bhadresh-savani/distilbert-base-uncased-emotion',
#  'bigcode/starcoder2-3b',
#  'bigscience/bloomz-560m',
#  'black-forest-labs/FLUX.1-schnell',
#  'blanchefort/rubert-base-cased-sentiment-rusentiment',
#  'blaze999/Medical-NER',
#  'bofenghuang/whisper-large-v3-french',
#  'bookbot/wav2vec2-ljspeech-gruut',
#  'botp/stable-diffusion-v1-5',
#  'briaai/RMBG-1.4',
#  'brunopio/Llama3-8B-1.58-100B-tokens-GGUF',
#  'cagliostrolab/animagine-xl-3.1',
#  'cahya/bert-base-indonesian-NER',
#  'cambridgeltl/SapBERT-from-PubMedBERT-fulltext',
#  'canerturkmen/bolt-test',
#  'cardiffnlp/twitter-roberta-base-sentiment-latest',
#  'casperhansen/mistral-nemo-instruct-2407-awq',
#  'cecibas/Midnight-Miqu-70B-v1.5-4bit',
#  'charactr/vocos-mel-24khz',
#  'charsiu/en_w2v2_fc_10ms',
#  'city96/FLUX.1-dev-gguf',
#  'ckiplab/bert-base-chinese-ws',
#  'cledoux42/Ethnicity_Test_v003',
#  'codesage/codesage-large',
#  'cointegrated/rubert-tiny',
#  'colbert-ir/colbertv2.0',
#  'coqui/XTTS-v2',
#  'cross-encoder/ms-marco-MiniLM-L-6-v2',
#  'crynux-ai/stable-diffusion-v1-5',
#  'csebuetnlp/banglat5_banglaparaphrase',
#  'dangvantuan/sentence-camembert-large',
#  'dataautogpt3/ProteusV0.3',
#  'datificate/gpt2-small-spanish',
#  'davebulaval/MeaningBERT',
#  'davidkim205/ko-gemma-2-9b-it',
#  'dbmdz/bert-large-cased-finetuned-conll03-english',
#  'dccuchile/bert-base-spanish-wwm-uncased',
#  'deepdml/faster-whisper-large-v3-turbo-ct2',
#  'deepset/roberta-base-squad2',
#  'depth-anything/Depth-Anything-V2-Large-hf',
#  'dicta-il/dictalm2.0-instruct',
#  'diffusers/stable-diffusion-xl-1.0-inpainting-0.1',
#  'distil-whisper/distil-large-v3',
#  'distilbert/distilbert-base-uncased',
#  'distributed/optimized-gpt2-1b',
#  'dmis-lab/biobert-v1.1',
#  'doc2query/msmarco-t5-base-v1',
#  'dslim/bert-base-NER',
#  'dtger/dt_style_1',
#  'dunzhang/stella_en_400M_v5',
#  'echarlaix/tiny-random-mistral',
#  'eenzeenee/t5-base-korean-summarization',
#  'ehcalabres/wav2vec2-lg-xlsr-en-speech-emotion-recognition',
#  'emilyalsentzer/Bio_ClinicalBERT',
#  'emrecan/bert-base-turkish-cased-mean-nli-stsb-tr',
#  'facebook/opt-1.3b',
#  'fal-collab-models/dreamshaper-xl-1-0',
#  'finiteautomata/beto-sentiment-analysis',
#  'fixie-ai/ultravox-v0_3',
#  'flair/ner-english-fast',
#  'furiosa-ai/mlperf-gpt-j-6b',
#  'fxmarty/really-tiny-falcon-testing',
#  'ggml-org/models',
#  'ggrazzioli/cls_sentimento_sebrae',
#  'ghunkins/prompt-expansion',
#  'gilf/french-camembert-postag-model',
#  'google/vit-base-patch16-224-in21k',
#  'google-bert/bert-base-uncased',
#  'google-t5/t5-small',
#  'h2oai/h2ogpt-4096-llama2-7b-chat',
#  'h94/IP-Adapter-FaceID',
#  'hfl/chinese-roberta-wwm-ext',
#  'hiiamsid/sentence_similarity_spanish_es',
#  'hkunlp/instructor-large',
#  'hpcai-tech/OpenSora-VAE-v1.2',
#  'huawei-noah/TinyBERT_General_4L_312D',
#  'hugging-quants/Llama-3.2-1B-Instruct-Q8_0-GGUF',
#  'huggyllama/llama-7b',
#  'hustvl/vitmatte-small-composition-1k',
#  'ibm-granite/granite-timeseries-ttm-r1',
#  'indobenchmark/indobert-base-p1',
#  'internlm/internlm-xcomposer2d5-clip',
#  'intfloat/e5-large-v2',
#  'j-hartmann/emotion-english-distilroberta-base',
#  'jbetker/wav2vec2-large-robust-ft-libritts-voxpopuli',
#  'jhgan/ko-sroberta-multitask',
#  'jinaai/jina-embeddings-v3',
#  'joeddav/xlm-roberta-large-xnli',
#  'jonatasgrosman/wav2vec2-large-xlsr-53-english',
#  'jonathandinu/face-parsing',
#  'jondurbin/unstuffer-v0.2',
#  'jordiclive/flan-t5-3b-summarizer',
#  'jtlicardo/bpmn-information-extraction-v2',
#  'jukofyork/creative-writing-control-vectors-v3.0',
#  'katuni4ka/tiny-random-baichuan2',
#  'kingabzpro/wav2vec2-large-xls-r-300m-Urdu',
#  'koheiduck/bert-japanese-finetuned-sentiment',
#  'kredor/punctuate-all',
#  'kresnik/wav2vec2-large-xlsr-korean',
#  'kuleshov-group/caduceus-ps_seqlen-131k_d_model-256_n_layer-16',
#  'kykim/bert-kor-base',
#  'kyutai/mimi',
#  'laion/CLIP-ViT-B-16-laion2B-s34B-b88K',
#  'latent-consistency/lcm-lora-sdv1-5',
#  'lengyue233/content-vec-best',
#  'lewtun/tiny-random-mt5',
#  'liuhaotian/llava-v1.5-7b',
#  'llamafactory/tiny-random-Llama-3',
#  'llava-hf/llava-v1.6-mistral-7b-hf',
#  'lllyasviel/sd-controlnet-canny',
#  'lmsys/vicuna-7b-v1.5',
#  'lucas-leme/FinBERT-PT-BR',
#  'lxyuan/distilbert-base-multilingual-cased-sentiments-student',
#  'madebyollin/sdxl-vae-fp16-fix',
#  'madhurjindal/autonlp-Gibberish-Detector-492513457',
#  'malteos/scincl',
#  'martin-ha/toxic-comment-model',
#  'mattmdjaga/segformer_b2_clothes',
#  'meta-llama/Llama-3.1-8B-Instruct',
#  'michaelfeil/bge-small-en-v1.5',
#  'michellejieli/emotion_text_classifier',
#  'microsoft/resnet-50',
#  'mistralai/Mistral-7B-Instruct-v0.3',
#  'mixedbread-ai/mxbai-embed-large-v1',
#  'ml6team/keyphrase-extraction-distilbert-inspec',
#  'modularai/llama-3.1',
#  'mohitsha/tiny-random-testing-bert2gpt2',
#  'moka-ai/m3e-base',
#  'monologg/kobert',
#  'mpoyraz/wav2vec2-xls-r-300m-cv7-turkish',
#  'mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis',
#  'mtg-upf/discogs-maest-30s-pw-129e',
#  'myshell-ai/MeloTTS-English',
#  'nateraw/vit-age-classifier',
#  'naver/splade-cocondenser-selfdistil',
#  'ncbi/MedCPT-Query-Encoder',
#  'nesaorg/benchmark_v0',
#  'neulab/codebert-java',
#  'neuralmagic/Meta-Llama-3.1-8B-Instruct-FP8',
#  'neuralmind/bert-base-portuguese-cased',
#  'nferruz/ProtGPT2',
#  'nfliu/deberta-v3-large_boolq',
#  'nguyenvulebinh/wav2vec2-base-vi',
#  'nlpaueb/legal-bert-base-uncased',
#  'nlpconnect/vit-gpt2-image-captioning',
#  'nlptown/bert-base-multilingual-uncased-sentiment',
#  'nomic-ai/nomic-embed-text-v1.5',
#  'ntu-spml/distilhubert',
#  'numind/NuNER_Zero',
#  'nvidia/speakerverification_en_titanet_large',
#  'obh07/multilingual-e5-base-dolly-15k',
#  'obi/deid_roberta_i2b2',
#  'oliverguhr/fullstop-punctuation-multilang-large',
#  'openai/clip-vit-large-patch14',
#  'openai-community/gpt2',
#  'openart-custom/AlbedoBase',
#  'openlm-research/open_llama_3b_v2',
#  'opensearch-project/opensearch-neural-sparse-encoding-doc-v2-distill',
#  'optimum-internal-testing/tiny-random-llama',
#  'owkin/phikon',
#  'padmajabfrl/Gender-Classification',
#  'papluca/xlm-roberta-base-language-detection',
#  'patrickjohncyh/fashion-clip',
#  'patrickvonplaten/wavlm-libri-clean-100h-base-plus',
#  'pdelobelle/robbert-v2-dutch-base',
#  'peft-internal-testing/tiny-dummy-qwen2',
#  'petals-team/StableBeluga2',
#  'philschmid/bart-large-cnn-samsum',
#  'pierreguillou/ner-bert-base-cased-pt-lenerbr',
#  'playgroundai/playground-v2.5-1024px-aesthetic',
#  'pparasurama/raceBERT-ethnicity',
#  'prajjwal1/bert-small',
#  'princeton-nlp/sup-simcse-roberta-large',
#  'prithivida/parrot_paraphraser_on_T5',
#  'prs-eth/marigold-normals-lcm-v0-1',
#  'pyannote/segmentation-3.0',
#  'pysentimiento/robertuito-sentiment-analysis',
#  'qanastek/51-languages-classifier',
#  'reazon-research/reazonspeech-nemo-v2',
#  'rinna/japanese-cloob-vit-b-16',
#  'rizvandwiki/gender-classification',
#  's-nlp/roberta_toxicity_classifier',
#  'salmanshahid/vad',
#  'sanchit-gandhi/whisper-medium-fleurs-lang-id',
#  'seara/rubert-tiny2-russian-sentiment',
#  'sentence-transformers/all-mpnet-base-v2',
#  'sentence-transformers-testing/stsb-bert-tiny-safetensors',
#  'sentinet/suicidality',
#  'shahrukhx01/bert-mini-finetune-question-detection',
#  'shi-labs/oneformer_coco_swin_large',
#  'shibing624/text2vec-base-chinese',
#  'smallcloudai/Refact-1_6B-fim',
#  'solidrust/Codestral-22B-v0.1-hf-AWQ',
#  'sonoisa/sentence-bert-base-ja-mean-tokens-v2',
#  'speechbrain/spkrec-ecapa-voxceleb',
#  'sshleifer/distilbart-cnn-12-6',
#  'stabilityai/stable-diffusion-xl-base-1.0',
#  'stable-diffusion-v1-5/stable-diffusion-inpainting',
#  'stablediffusionapi/realistic-vision-51',
#  'stepfun-ai/GOT-OCR2_0',
#  'tasksource/deberta-small-long-nli',
#  'tencent/DepthCrafter',
#  'textattack/bert-base-uncased-snli',
#  'theainerd/Wav2Vec2-large-xlsr-hindi',
#  'thenlper/gte-large',
#  'tiiuae/falcon-7b-instruct',
#  'timbrooks/instruct-pix2pix',
#  'timm/resnet50.a1_in1k',
#  'timpal0l/mdeberta-v3-base-squad2',
#  'tner/roberta-large-ontonotes5',
#  'to-be/donut-base-finetuned-invoices',
#  'tohoku-nlp/bert-base-japanese',
#  'trl-internal-testing/tiny-random-LlamaForCausalLM',
#  'trpakov/vit-face-expression',
#  'tsmatz/xlm-roberta-ner-japanese',
#  'tuner007/pegasus_paraphrase',
#  'ufal/robeczech-base',
#  'unitary/toxic-bert',
#  'unsloth/llama-3-8b-bnb-4bit',
#  'unslothai/1',
#  'vectara/hallucination_evaluation_model',
#  'vikhyatk/moondream2',
#  'vikp/surya_det3',
#  'vinai/phobert-base-v2',
#  'vinid/plip',
#  'w11wo/indonesian-roberta-base-posp-tagger',
#  'wangqixun/YamerMIX_v8',
#  'wasmdashai/wasmai-7b-v1',
#  'xiaxy/elastic-bert-chinese-ner',
#  'xlnet/xlnet-base-cased',
#  'yangheng/deberta-v3-base-absa-v1.1',
#  'ybelkada/tiny-random-T5ForConditionalGeneration-calibrated',
#  'yikuan8/Clinical-Longformer',
#  'yiyanghkust/finbert-tone',
#  'yosuke/bert-base-japanese-char',
#  'zer0int/CLIP-GmP-ViT-L-14']

# %% [markdown]
# Saving into a csv the information about the 363 models. The columns saved are modelId, size, datasets, dataset_size, downloads, likes, library_name, created_at, commits and files.

# %%
models_information = []
for model_id in models_id:
    print(f"Processing model: {model_id}")
    processed_model = process_model(model_id)
    if processed_model:
        models_information.append(processed_model)

df = pd.DataFrame(models_information)
df.to_csv('HF_topmodels.csv', index=False)
print(f"Processed {len(models_information)} models. Results saved to 'HF_topmodels.csv'.")
# Out:
# Processing model: 1-800-BAD-CODE/punctuation_fullstop_truecase_english
# Model 1-800-BAD-CODE/punctuation_fullstop_truecase_english, Size: 587902 bytes
# Processing model: AdamCodd/vit-base-nsfw-detector
# /home/maria/.local/lib/python3.10/site-packages/huggingface_hub/repocard_data.py:306: UserWarning: Invalid model-index. Not loading eval results into CardData.
#   warnings.warn("Invalid model-index. Not loading eval results into CardData.")
# Model AdamCodd/vit-base-nsfw-detector, Size: 344391328 bytes
# Processing model: Alibaba-NLP/gte-large-en-v1.5
# Model Alibaba-NLP/gte-large-en-v1.5, Size: 1736585680 bytes
# Processing model: Ashishkr/query_wellformedness_score
# Model Ashishkr/query_wellformedness_score, Size: 501040705 bytes
# Processing model: AutonLab/MOMENT-1-large
# Model AutonLab/MOMENT-1-large, Size: 1385575757 bytes
# Processing model: BAAI/bge-small-en-v1.5
# Model BAAI/bge-small-en-v1.5, Size: 133508397 bytes
# Processing model: Babelscape/wikineural-multilingual-ner
# Model Babelscape/wikineural-multilingual-ner, Size: 709170662 bytes
# Processing model: BridgeTower/bridgetower-large-itm-mlm-itc
# Model BridgeTower/bridgetower-large-itm-mlm-itc, Size: 3681345984 bytes
# Processing model: ByteDance/Hyper-SD
# Model ByteDance/Hyper-SD, Size: 27739238686 bytes
# Processing model: CIDAS/clipseg-rd64-refined
# Model CIDAS/clipseg-rd64-refined, Size: 603143713 bytes
# Processing model: Cloudy1225/stackoverflow-roberta-base-sentiment
# Model Cloudy1225/stackoverflow-roberta-base-sentiment, Size: 498663405 bytes
# Processing model: CompVis/stable-diffusion-safety-checker
# Model CompVis/stable-diffusion-safety-checker, Size: 1216067303 bytes
# Processing model: Danswer/intent-model
# Model Danswer/intent-model, Size: 267954880 bytes
# Processing model: DeepChem/ChemBERTa-77M-MTR
# Model DeepChem/ChemBERTa-77M-MTR, Size: 14038865 bytes
# Processing model: DeepFloyd/t5-v1_1-xxl
# Model DeepFloyd/t5-v1_1-xxl, Size: 19049317384 bytes
# Processing model: DeepPavlov/rubert-base-cased
# Model DeepPavlov/rubert-base-cased, Size: 714355318 bytes
# Processing model: Dmyadav2001/Sentimental-Analysis
# Model Dmyadav2001/Sentimental-Analysis, Size: 267835644 bytes
# Processing model: Efficient-Large-Model/Llama-3-VILA1.5-8B-Fix
# Model Efficient-Large-Model/Llama-3-VILA1.5-8B-Fix, Size: 16988417392 bytes
# Processing model: EleutherAI/gpt-neo-2.7B
# Model EleutherAI/gpt-neo-2.7B, Size: 10672498931 bytes
# Processing model: EmergentMethods/gliner_medium_news-v2.1
# Model EmergentMethods/gliner_medium_news-v2.1, Size: 780807790 bytes
# Processing model: Ericwang/tiny-random-ast
# Model Ericwang/tiny-random-ast, Size: 335542 bytes
# Processing model: FacebookAI/xlm-roberta-large
# Model FacebookAI/xlm-roberta-large, Size: 2244861551 bytes
# Processing model: Falconsai/nsfw_image_detection
# Model Falconsai/nsfw_image_detection, Size: 343268717 bytes
# Processing model: Gustavosta/MagicPrompt-Stable-Diffusion
# Model Gustavosta/MagicPrompt-Stable-Diffusion, Size: 1503691006 bytes
# Processing model: Hate-speech-CNERG/tamil-codemixed-abusive-MuRIL
# Model Hate-speech-CNERG/tamil-codemixed-abusive-MuRIL, Size: 950313261 bytes
# Processing model: Helsinki-NLP/opus-mt-fr-en
# Model Helsinki-NLP/opus-mt-fr-en, Size: 300827685 bytes
# Processing model: HooshvareLab/bert-fa-base-uncased-ner-peyma
# Model HooshvareLab/bert-fa-base-uncased-ner-peyma, Size: 651500422 bytes
# Processing model: HuggingFaceH4/zephyr-7b-beta
# Model HuggingFaceH4/zephyr-7b-beta, Size: 14483561646 bytes
# Processing model: HuggingFaceM4/siglip-so400m-14-384
# Model HuggingFaceM4/siglip-so400m-14-384, Size: 3512146093 bytes
# Processing model: IDEA-Research/grounding-dino-tiny
# Model IDEA-Research/grounding-dino-tiny, Size: 691914602 bytes
# Processing model: InstantX/InstantID
# Model InstantX/InstantID, Size: 1691134141 bytes
# Processing model: Intel/dpt-hybrid-midas
# Model Intel/dpt-hybrid-midas, Size: 489648389 bytes
# Processing model: Isotr0py/test-gguf-sample
# Model Isotr0py/test-gguf-sample, Size: 297469760 bytes
# Processing model: JackFram/llama-68m
# Model JackFram/llama-68m, Size: 272132529 bytes
# Processing model: Jean-Baptiste/camembert-ner-with-dates
# Model Jean-Baptiste/camembert-ner-with-dates, Size: 440233263 bytes
# Processing model: LTP/small
# Model LTP/small, Size: 179675533 bytes
# Processing model: Lajavaness/bilingual-embedding-large
# Model Lajavaness/bilingual-embedding-large, Size: 2239607176 bytes
# Processing model: LanguageBind/LanguageBind_Video_FT
# Model LanguageBind/LanguageBind_Video_FT, Size: 2114783469 bytes
# Processing model: Leo97/KoELECTRA-small-v3-modu-ner
# Model Leo97/KoELECTRA-small-v3-modu-ner, Size: 56333680 bytes
# Processing model: LiheYoung/depth-anything-large-hf
# Model LiheYoung/depth-anything-large-hf, Size: 1341322868 bytes
# Processing model: Lykon/DreamShaper
# Model Lykon/DreamShaper, Size: 5481450296 bytes
# Processing model: M-CLIP/XLM-Roberta-Large-Vit-B-32
# Model M-CLIP/XLM-Roberta-Large-Vit-B-32, Size: 2241822765 bytes
# Processing model: MCG-NJU/videomae-large
# Model MCG-NJU/videomae-large, Size: 1372166773 bytes
# Processing model: MIT/ast-finetuned-audioset-10-10-0.4593
# Model MIT/ast-finetuned-audioset-10-10-0.4593, Size: 346445675 bytes
# Processing model: MMG/xlm-roberta-large-ner-spanish
# Model MMG/xlm-roberta-large-ner-spanish, Size: 2235563462 bytes
# Processing model: MRNH/mbart-english-grammar-corrector
# Model MRNH/mbart-english-grammar-corrector, Size: 2444706333 bytes
# Processing model: MahmoudAshraf/mms-300m-1130-forced-aligner
# Model MahmoudAshraf/mms-300m-1130-forced-aligner, Size: 1262019174 bytes
# Processing model: Marqo/marqo-fashionSigLIP
# Model Marqo/marqo-fashionSigLIP, Size: 812750942 bytes
# Processing model: MattyB95/AST-VoxCelebSpoof-Synthetic-Voice-Detection
# Model MattyB95/AST-VoxCelebSpoof-Synthetic-Voice-Detection, Size: 4856 bytes
# Processing model: Maykeye/TinyLLama-v0
# Model Maykeye/TinyLLama-v0, Size: 18545983 bytes
# Processing model: MaziyarPanahi/Mistral-7B-Instruct-v0.3-GGUF
# Model MaziyarPanahi/Mistral-7B-Instruct-v0.3-GGUF, Size: 72552876352 bytes
# Processing model: Michau/t5-base-en-generate-headline
# Model Michau/t5-base-en-generate-headline, Size: 891695056 bytes
# Processing model: Minej/bert-base-personality
# Model Minej/bert-base-personality, Size: 438017141 bytes
# Processing model: Moritz-Pfeifer/CentralBankRoBERTa-sentiment-classifier
# Model Moritz-Pfeifer/CentralBankRoBERTa-sentiment-classifier, Size: 498677936 bytes
# Processing model: MoritzLaurer/DeBERTa-v3-base-mnli-fever-anli
# Model MoritzLaurer/DeBERTa-v3-base-mnli-fever-anli, Size: 368935915 bytes
# Processing model: NbAiLab/nb-wav2vec2-300m-nynorsk
# Model NbAiLab/nb-wav2vec2-300m-nynorsk, Size: 5243822699 bytes
# Processing model: NeuML/pubmedbert-base-embeddings
# Model NeuML/pubmedbert-base-embeddings, Size: 437995689 bytes
# Processing model: NlpHUST/ner-vietnamese-electra-base
# Model NlpHUST/ner-vietnamese-electra-base, Size: 532365681 bytes
# Processing model: NousResearch/Llama-2-7b-chat-hf
# Model NousResearch/Llama-2-7b-chat-hf, Size: 26953781249 bytes
# Processing model: OpenAssistant/oasst-sft-4-pythia-12b-epoch-3.5
# Model OpenAssistant/oasst-sft-4-pythia-12b-epoch-3.5, Size: 23835137461 bytes
# Processing model: OpenGVLab/InternVL2-8B
# Model OpenGVLab/InternVL2-8B, Size: 16150800432 bytes
# Processing model: Orenguteng/Llama-3-8B-Lexi-Uncensored
# Model Orenguteng/Llama-3-8B-Lexi-Uncensored, Size: 17671168912 bytes
# Processing model: ProsusAI/finbert
# Model ProsusAI/finbert, Size: 437992753 bytes
# Processing model: Qdrant/all-MiniLM-L6-v2-onnx
# Model Qdrant/all-MiniLM-L6-v2-onnx, Size: 90387630 bytes
# Processing model: Qwen/Qwen2.5-1.5B-Instruct
# Model Qwen/Qwen2.5-1.5B-Instruct, Size: 3087467144 bytes
# Processing model: RishuD7/CML_Text_date_number_blank_v1
# Model RishuD7/CML_Text_date_number_blank_v1, Size: 990413610 bytes
# Processing model: Rostlab/prot_bert
# Model Rostlab/prot_bert, Size: 1684058277 bytes
# Processing model: RunDiffusion/Juggernaut-XL-v9
# Model RunDiffusion/Juggernaut-XL-v9, Size: 14043359618 bytes
# Processing model: SG161222/RealVisXL_V4.0
# Model SG161222/RealVisXL_V4.0, Size: 27751743412 bytes
# Processing model: SWivid/F5-TTS
# Model SWivid/F5-TTS, Size: 1348645281 bytes
# Processing model: Salesforce/blip-image-captioning-large
# Model Salesforce/blip-image-captioning-large, Size: 1879143921 bytes
# Processing model: SamLowe/roberta-base-go_emotions
# Model SamLowe/roberta-base-go_emotions, Size: 498740269 bytes
# Processing model: SanctumAI/Meta-Llama-3.1-8B-Instruct-GGUF
# Model SanctumAI/Meta-Llama-3.1-8B-Instruct-GGUF, Size: 99448680384 bytes
# Processing model: SenswiseData/bert_cased_ner
# Model SenswiseData/bert_cased_ner, Size: 440217663 bytes
# Processing model: Shakker-Labs/FLUX.1-dev-LoRA-AntiBlur
# Model Shakker-Labs/FLUX.1-dev-LoRA-AntiBlur, Size: 687476088 bytes
# Processing model: Snowflake/snowflake-arctic-embed-m
# Model Snowflake/snowflake-arctic-embed-m, Size: 435588776 bytes
# Processing model: SpanBERT/spanbert-large-cased
# Model SpanBERT/spanbert-large-cased, Size: 665132540 bytes
# Processing model: Sudanl/stable-diffusion-2-1-base-custom
# Model Sudanl/stable-diffusion-2-1-base-custom, Size: 1278518342 bytes
# Processing model: Supabase/gte-small
# Model Supabase/gte-small, Size: 66751231 bytes
# Processing model: Systran/faster-whisper-large-v3
# Model Systran/faster-whisper-large-v3, Size: 3087284237 bytes
# Processing model: T-Systems-onsite/cross-en-de-roberta-sentence-transformer
# Model T-Systems-onsite/cross-en-de-roberta-sentence-transformer, Size: 1112261175 bytes
# Processing model: THUDM/chatglm2-6b
# Model THUDM/chatglm2-6b, Size: 12487241401 bytes
# Processing model: TahaDouaji/detr-doc-table-detection
# Model TahaDouaji/detr-doc-table-detection, Size: 166637077 bytes
# Processing model: TaylorAI/bge-micro-v2
# Model TaylorAI/bge-micro-v2, Size: 34797782 bytes
# Processing model: Team-ACE/ToolACE-8B
# Model Team-ACE/ToolACE-8B, Size: 16060556376 bytes
# Processing model: TheBloke/Mistral-7B-Instruct-v0.2-GPTQ
# Model TheBloke/Mistral-7B-Instruct-v0.2-GPTQ, Size: 4158662280 bytes
# Processing model: TinyLlama/TinyLlama-1.1B-Chat-v1.0
# Model TinyLlama/TinyLlama-1.1B-Chat-v1.0, Size: 2200119864 bytes
# Processing model: Tochka-AI/ruRoPEBert-e5-base-2k
# Model Tochka-AI/ruRoPEBert-e5-base-2k, Size: 556038216 bytes
# Processing model: UFNLP/gatortron-base
# Model UFNLP/gatortron-base, Size: 712850277 bytes
# Processing model: VAGOsolutions/Llama-3.1-SauerkrautLM-8b-Instruct
# Model VAGOsolutions/Llama-3.1-SauerkrautLM-8b-Instruct, Size: 16060556376 bytes
# Processing model: WhereIsAI/UAE-Large-V1
# Model WhereIsAI/UAE-Large-V1, Size: 1673132720 bytes
# Processing model: WinKawaks/vit-tiny-patch16-224
# Model WinKawaks/vit-tiny-patch16-224, Size: 33617713 bytes
# Processing model: XLabs-AI/flux-RealismLora
# Model XLabs-AI/flux-RealismLora, Size: 22431400 bytes
# Processing model: Xenova/bge-base-en-v1.5
# Model Xenova/bge-base-en-v1.5, Size: 764003112 bytes
# Processing model: Yehor/w2v-xls-r-uk
# Model Yehor/w2v-xls-r-uk, Size: 1261971432 bytes
# Processing model: YituTech/conv-bert-base
# Model YituTech/conv-bert-base, Size: 422840281 bytes
# Processing model: YxZhang/evf-sam2-multitask
# Model YxZhang/evf-sam2-multitask, Size: 1797531652 bytes
# Processing model: ZhengPeng7/BiRefNet
# Model ZhengPeng7/BiRefNet, Size: 884878856 bytes
# Processing model: adrianjoheni/translation-model-opus
# Model adrianjoheni/translation-model-opus, Size: 312087523 bytes
# Processing model: adsabs/astroBERT
# Model adsabs/astroBERT, Size: 438904355 bytes
# Processing model: aglazkova/bart_finetuned_keyphrase_extraction
# Model aglazkova/bart_finetuned_keyphrase_extraction, Size: 557974744 bytes
# Processing model: ai-forever/sbert_large_nlu_ru
# Model ai-forever/sbert_large_nlu_ru, Size: 1707761510 bytes
# Processing model: ai4bharat/indic-bert
# Model ai4bharat/indic-bert, Size: 134982446 bytes
# Processing model: ailegends/xlsr-jonatasgrosman-wav2vec2-large-xlsr-53-english
# Model ailegends/xlsr-jonatasgrosman-wav2vec2-large-xlsr-53-english, Size: 1262031277 bytes
# Processing model: aipicasso/emi
# Need authorization to retrieve model size from aipicasso/emi.
# Model aipicasso/emi, Size: None bytes
# Processing model: albert/albert-base-v2
# Model albert/albert-base-v2, Size: 47376696 bytes
# Processing model: alefiury/wav2vec2-large-xlsr-53-gender-recognition-librispeech
# Model alefiury/wav2vec2-large-xlsr-53-gender-recognition-librispeech, Size: 1262957808 bytes
# Processing model: ali-vilab/In-Context-LoRA
# Model ali-vilab/In-Context-LoRA, Size: 1719693568 bytes
# Processing model: allenai/longformer-base-4096
# Model allenai/longformer-base-4096, Size: 597257159 bytes
# Processing model: almanach/camembert-base
# Model almanach/camembert-base, Size: 445032417 bytes
# Processing model: amazon/chronos-t5-small
# Model amazon/chronos-t5-small, Size: 184632480 bytes
# Processing model: amunchet/rorshark-vit-base
# Model amunchet/rorshark-vit-base, Size: 4728 bytes
# Processing model: answerdotai/answerai-colbert-small-v1
# Model answerdotai/answerai-colbert-small-v1, Size: 133610664 bytes
# Processing model: anton-l/wav2vec2-random-tiny-classifier
# Model anton-l/wav2vec2-random-tiny-classifier, Size: 94607 bytes
# Processing model: apple/OpenELM-1_1B-Instruct
# Model apple/OpenELM-1_1B-Instruct, Size: 2159808696 bytes
# Processing model: argmaxinc/whisperkit-coreml
# Model argmaxinc/whisperkit-coreml, Size: 27197680366 bytes
# Processing model: artificialguybr/ColoringBookRedmond-V2
# Model artificialguybr/ColoringBookRedmond-V2, Size: 170540036 bytes
# Processing model: ashawkey/mvdream-sd2.1-diffusers
# Model ashawkey/mvdream-sd2.1-diffusers, Size: 2583380278 bytes
# Processing model: aspire/acge_text_embedding
# Model aspire/acge_text_embedding, Size: 655903020 bytes
# Processing model: aubmindlab/bert-base-arabertv02
# Model aubmindlab/bert-base-arabertv02, Size: 543490667 bytes
# Processing model: audeering/wav2vec2-large-robust-24-ft-age-gender
# Model audeering/wav2vec2-large-robust-24-ft-age-gender, Size: 1270310981 bytes
# Processing model: autogluon/chronos-t5-tiny
# Model autogluon/chronos-t5-tiny, Size: 33588440 bytes
# Processing model: avsolatorio/GIST-small-Embedding-v0
# Model avsolatorio/GIST-small-Embedding-v0, Size: 133504422 bytes
# Processing model: bartowski/Meta-Llama-3.1-8B-Instruct-GGUF
# Model bartowski/Meta-Llama-3.1-8B-Instruct-GGUF, Size: 143449204192 bytes
# Processing model: basel/ATTACK-BERT
# Model basel/ATTACK-BERT, Size: 438016493 bytes
# Processing model: benjamin/wtp-canine-s-1l
# Model benjamin/wtp-canine-s-1l, Size: 805658603 bytes
# Processing model: bespin-global/klue-sroberta-base-continue-learning-by-mnr
# Model bespin-global/klue-sroberta-base-continue-learning-by-mnr, Size: 442554737 bytes
# Processing model: bhadresh-savani/distilbert-base-uncased-emotion
# Model bhadresh-savani/distilbert-base-uncased-emotion, Size: 267875479 bytes
# Processing model: bigcode/starcoder2-3b
# Model bigcode/starcoder2-3b, Size: 12121539344 bytes
# Processing model: bigscience/bloomz-560m
# Model bigscience/bloomz-560m, Size: 1118530423 bytes
# Processing model: black-forest-labs/FLUX.1-schnell
# Model black-forest-labs/FLUX.1-schnell, Size: 57838764946 bytes
# Processing model: blanchefort/rubert-base-cased-sentiment-rusentiment
# Model blanchefort/rubert-base-cased-sentiment-rusentiment, Size: 711509513 bytes
# Processing model: blaze999/Medical-NER
# Model blaze999/Medical-NER, Size: 4664 bytes
# Processing model: bofenghuang/whisper-large-v3-french
# Model bofenghuang/whisper-large-v3-french, Size: 7263457923 bytes
# Processing model: bookbot/wav2vec2-ljspeech-gruut
# Model bookbot/wav2vec2-ljspeech-gruut, Size: 377700230 bytes
# Processing model: botp/stable-diffusion-v1-5
# Model botp/stable-diffusion-v1-5, Size: 5481429076 bytes
# Processing model: briaai/RMBG-1.4
# Model briaai/RMBG-1.4, Size: 176574018 bytes
# Processing model: brunopio/Llama3-8B-1.58-100B-tokens-GGUF
# Model brunopio/Llama3-8B-1.58-100B-tokens-GGUF, Size: 3846768552 bytes
# Processing model: cagliostrolab/animagine-xl-3.1
# Model cagliostrolab/animagine-xl-3.1, Size: 13876337206 bytes
# Processing model: cahya/bert-base-indonesian-NER
# Model cahya/bert-base-indonesian-NER, Size: 442643905 bytes
# Processing model: cambridgeltl/SapBERT-from-PubMedBERT-fulltext
# Model cambridgeltl/SapBERT-from-PubMedBERT-fulltext, Size: 438012727 bytes
# Processing model: canerturkmen/bolt-test
# Model canerturkmen/bolt-test, Size: 1382728 bytes
# Processing model: cardiffnlp/twitter-roberta-base-sentiment-latest
# Model cardiffnlp/twitter-roberta-base-sentiment-latest, Size: 501045531 bytes
# Processing model: casperhansen/mistral-nemo-instruct-2407-awq
# Model casperhansen/mistral-nemo-instruct-2407-awq, Size: 8350876072 bytes
# Processing model: cecibas/Midnight-Miqu-70B-v1.5-4bit
# Model cecibas/Midnight-Miqu-70B-v1.5-4bit, Size: 36614297249 bytes
# Processing model: charactr/vocos-mel-24khz
# Model charactr/vocos-mel-24khz, Size: 54365991 bytes
# Processing model: charsiu/en_w2v2_fc_10ms
# Model charsiu/en_w2v2_fc_10ms, Size: 377706220 bytes
# Processing model: city96/FLUX.1-dev-gguf
# Model city96/FLUX.1-dev-gguf, Size: 102328509792 bytes
# Processing model: ckiplab/bert-base-chinese-ws
# Model ckiplab/bert-base-chinese-ws, Size: 406802935 bytes
# Processing model: cledoux42/Ethnicity_Test_v003
# Model cledoux42/Ethnicity_Test_v003, Size: 344445293 bytes
# Processing model: codesage/codesage-large
# Model codesage/codesage-large, Size: 5253949145 bytes
# Processing model: cointegrated/rubert-tiny
# Model cointegrated/rubert-tiny, Size: 306348035 bytes
# Processing model: colbert-ir/colbertv2.0
# Model colbert-ir/colbertv2.0, Size: 438405935 bytes
# Processing model: coqui/XTTS-v2
# Model coqui/XTTS-v2, Size: 2086199391 bytes
# Processing model: cross-encoder/ms-marco-MiniLM-L-6-v2
# Model cross-encoder/ms-marco-MiniLM-L-6-v2, Size: 90903017 bytes
# Processing model: crynux-ai/stable-diffusion-v1-5
# Model crynux-ai/stable-diffusion-v1-5, Size: 7005697050 bytes
# Processing model: csebuetnlp/banglat5_banglaparaphrase
# Model csebuetnlp/banglat5_banglaparaphrase, Size: 990276360 bytes
# Processing model: dangvantuan/sentence-camembert-large
# Model dangvantuan/sentence-camembert-large, Size: 1346812279 bytes
# Processing model: dataautogpt3/ProteusV0.3
# Model dataautogpt3/ProteusV0.3, Size: 13876435420 bytes
# Processing model: datificate/gpt2-small-spanish
# Model datificate/gpt2-small-spanish, Size: 510408315 bytes
# Processing model: davebulaval/MeaningBERT
# Model davebulaval/MeaningBERT, Size: 437955572 bytes
# Processing model: davidkim205/ko-gemma-2-9b-it
# Model davidkim205/ko-gemma-2-9b-it, Size: 18483466448 bytes
# Processing model: dbmdz/bert-large-cased-finetuned-conll03-english
# Model dbmdz/bert-large-cased-finetuned-conll03-english, Size: 1334448817 bytes
# Processing model: dccuchile/bert-base-spanish-wwm-uncased
# Model dccuchile/bert-base-spanish-wwm-uncased, Size: 439621341 bytes
# Processing model: deepdml/faster-whisper-large-v3-turbo-ct2
# Model deepdml/faster-whisper-large-v3-turbo-ct2, Size: 1617884929 bytes
# Processing model: deepset/roberta-base-squad2
# Model deepset/roberta-base-squad2, Size: 496313727 bytes
# Processing model: depth-anything/Depth-Anything-V2-Large-hf
# Model depth-anything/Depth-Anything-V2-Large-hf, Size: 1341322868 bytes
# Processing model: dicta-il/dictalm2.0-instruct
# Model dicta-il/dictalm2.0-instruct, Size: 14502372384 bytes
# Processing model: diffusers/stable-diffusion-xl-1.0-inpainting-0.1
# Model diffusers/stable-diffusion-xl-1.0-inpainting-0.1, Size: 20813789103 bytes
# Processing model: distil-whisper/distil-large-v3
# Model distil-whisper/distil-large-v3, Size: 4538560848 bytes
# Processing model: distilbert/distilbert-base-uncased
# Model distilbert/distilbert-base-uncased, Size: 267967963 bytes
# Processing model: distributed/optimized-gpt2-1b
# Model distributed/optimized-gpt2-1b, Size: 4040701744 bytes
# Processing model: dmis-lab/biobert-v1.1
# Model dmis-lab/biobert-v1.1, Size: 433286112 bytes
# Processing model: doc2query/msmarco-t5-base-v1
# Model doc2query/msmarco-t5-base-v1, Size: 990448392 bytes
# Processing model: dslim/bert-base-NER
# Model dslim/bert-base-NER, Size: 433316646 bytes
# Processing model: dtger/dt_style_1
# Model dtger/dt_style_1, Size: 1301152968 bytes
# Processing model: dunzhang/stella_en_400M_v5
# Model dunzhang/stella_en_400M_v5, Size: 1866828194 bytes
# Processing model: echarlaix/tiny-random-mistral
# Model echarlaix/tiny-random-mistral, Size: 8252272 bytes
# Processing model: eenzeenee/t5-base-korean-summarization
# Model eenzeenee/t5-base-korean-summarization, Size: 1102417584 bytes
# Processing model: ehcalabres/wav2vec2-lg-xlsr-en-speech-emotion-recognition
# Model ehcalabres/wav2vec2-lg-xlsr-en-speech-emotion-recognition, Size: 1266158492 bytes
# Processing model: emilyalsentzer/Bio_ClinicalBERT
# Model emilyalsentzer/Bio_ClinicalBERT, Size: 435778770 bytes
# Processing model: emrecan/bert-base-turkish-cased-mean-nli-stsb-tr
# Model emrecan/bert-base-turkish-cased-mean-nli-stsb-tr, Size: 442547953 bytes
# Processing model: facebook/opt-1.3b
# Model facebook/opt-1.3b, Size: 2631639353 bytes
# Processing model: fal-collab-models/dreamshaper-xl-1-0
# Model fal-collab-models/dreamshaper-xl-1-0, Size: 6938011430 bytes
# Processing model: finiteautomata/beto-sentiment-analysis
# Model finiteautomata/beto-sentiment-analysis, Size: 439512342 bytes
# Processing model: fixie-ai/ultravox-v0_3
# Model fixie-ai/ultravox-v0_3, Size: 16127690536 bytes
# Processing model: flair/ner-english-fast
# Model flair/ner-english-fast, Size: 243635891 bytes
# Processing model: furiosa-ai/mlperf-gpt-j-6b
# Model furiosa-ai/mlperf-gpt-j-6b, Size: 24203664759 bytes
# Processing model: fxmarty/really-tiny-falcon-testing
# Model fxmarty/really-tiny-falcon-testing, Size: 8418910 bytes
# Processing model: ggml-org/models
# Model ggml-org/models, Size: 15981601280 bytes
# Processing model: ggrazzioli/cls_sentimento_sebrae
# Model ggrazzioli/cls_sentimento_sebrae, Size: 435774581 bytes
# Processing model: ghunkins/prompt-expansion
# Model ghunkins/prompt-expansion, Size: 351283802 bytes
# Processing model: gilf/french-camembert-postag-model
# Model gilf/french-camembert-postag-model, Size: 442628805 bytes
# Processing model: google/vit-base-patch16-224-in21k
# Model google/vit-base-patch16-224-in21k, Size: 345636463 bytes
# Processing model: google-bert/bert-base-uncased
# Model google-bert/bert-base-uncased, Size: 972306989 bytes
# Processing model: google-t5/t5-small
# Model google-t5/t5-small, Size: 242065649 bytes
# Processing model: h2oai/h2ogpt-4096-llama2-7b-chat
# Model h2oai/h2ogpt-4096-llama2-7b-chat, Size: 13476950097 bytes
# Processing model: h94/IP-Adapter-FaceID
# Model h94/IP-Adapter-FaceID, Size: 4857081668 bytes
# Processing model: hfl/chinese-roberta-wwm-ext
# Model hfl/chinese-roberta-wwm-ext, Size: 411578458 bytes
# Processing model: hiiamsid/sentence_similarity_spanish_es
# Model hiiamsid/sentence_similarity_spanish_es, Size: 439484849 bytes
# Processing model: hkunlp/instructor-large
# Model hkunlp/instructor-large, Size: 1342970470 bytes
# Processing model: hpcai-tech/OpenSora-VAE-v1.2
# Model hpcai-tech/OpenSora-VAE-v1.2, Size: 1573430548 bytes
# Processing model: huawei-noah/TinyBERT_General_4L_312D
# Model huawei-noah/TinyBERT_General_4L_312D, Size: 62747391 bytes
# Processing model: hugging-quants/Llama-3.2-1B-Instruct-Q8_0-GGUF
# Model hugging-quants/Llama-3.2-1B-Instruct-Q8_0-GGUF, Size: 1321079200 bytes
# Processing model: huggyllama/llama-7b
# Model huggyllama/llama-7b, Size: 13476950097 bytes
# Processing model: hustvl/vitmatte-small-composition-1k
# Model hustvl/vitmatte-small-composition-1k, Size: 103349013 bytes
# Processing model: ibm-granite/granite-timeseries-ttm-r1
# Model ibm-granite/granite-timeseries-ttm-r1, Size: 3240592 bytes
# Processing model: indobenchmark/indobert-base-p1
# Model indobenchmark/indobert-base-p1, Size: 497810400 bytes
# Processing model: internlm/internlm-xcomposer2d5-clip
# Model internlm/internlm-xcomposer2d5-clip, Size: 1218353513 bytes
# Processing model: intfloat/e5-large-v2
# Model intfloat/e5-large-v2, Size: 1340698349 bytes
# Processing model: j-hartmann/emotion-english-distilroberta-base
# Model j-hartmann/emotion-english-distilroberta-base, Size: 328546776 bytes
# Processing model: jbetker/wav2vec2-large-robust-ft-libritts-voxpopuli
# Model jbetker/wav2vec2-large-robust-ft-libritts-voxpopuli, Size: 1262524593 bytes
# Processing model: jhgan/ko-sroberta-multitask
# Model jhgan/ko-sroberta-multitask, Size: 442558967 bytes
# Processing model: jinaai/jina-embeddings-v3
# Model jinaai/jina-embeddings-v3, Size: 1144846522 bytes
# Processing model: joeddav/xlm-roberta-large-xnli
# Model joeddav/xlm-roberta-large-xnli, Size: 2243942751 bytes
# Processing model: jonatasgrosman/wav2vec2-large-xlsr-53-english
# Model jonatasgrosman/wav2vec2-large-xlsr-53-english, Size: 1262069143 bytes
# Processing model: jonathandinu/face-parsing
# Model jonathandinu/face-parsing, Size: 338821701 bytes
# Processing model: jondurbin/unstuffer-v0.2
# Model jondurbin/unstuffer-v0.2, Size: 1421495416 bytes
# Processing model: jordiclive/flan-t5-3b-summarizer
# Model jordiclive/flan-t5-3b-summarizer, Size: 5699596111 bytes
# Processing model: jtlicardo/bpmn-information-extraction-v2
# Model jtlicardo/bpmn-information-extraction-v2, Size: 430988200 bytes
# Processing model: jukofyork/creative-writing-control-vectors-v3.0
# Model jukofyork/creative-writing-control-vectors-v3.0, Size: 2941655808 bytes
# Processing model: katuni4ka/tiny-random-baichuan2
# Model katuni4ka/tiny-random-baichuan2, Size: 131293504 bytes
# Processing model: kingabzpro/wav2vec2-large-xls-r-300m-Urdu
# Model kingabzpro/wav2vec2-large-xls-r-300m-Urdu, Size: 1427305897 bytes
# Processing model: koheiduck/bert-japanese-finetuned-sentiment
# Model koheiduck/bert-japanese-finetuned-sentiment, Size: 442556228 bytes
# Processing model: kredor/punctuate-all
# Model kredor/punctuate-all, Size: 1109904928 bytes
# Processing model: kresnik/wav2vec2-large-xlsr-korean
# Model kresnik/wav2vec2-large-xlsr-korean, Size: 1266867168 bytes
# Processing model: kuleshov-group/caduceus-ps_seqlen-131k_d_model-256_n_layer-16
# Model kuleshov-group/caduceus-ps_seqlen-131k_d_model-256_n_layer-16, Size: 30937760 bytes
# Processing model: kykim/bert-kor-base
# Model kykim/bert-kor-base, Size: 475782997 bytes
# Processing model: kyutai/mimi
# Model kyutai/mimi, Size: 384649828 bytes
# Processing model: laion/CLIP-ViT-B-16-laion2B-s34B-b88K
# Model laion/CLIP-ViT-B-16-laion2B-s34B-b88K, Size: 598529951 bytes
# Processing model: latent-consistency/lcm-lora-sdv1-5
# Model latent-consistency/lcm-lora-sdv1-5, Size: 134621556 bytes
# Processing model: lengyue233/content-vec-best
# Model lengyue233/content-vec-best, Size: 378342945 bytes
# Processing model: lewtun/tiny-random-mt5
# Model lewtun/tiny-random-mt5, Size: 18092403 bytes
# Processing model: liuhaotian/llava-v1.5-7b
# Model liuhaotian/llava-v1.5-7b, Size: 13560871894 bytes
# Processing model: llamafactory/tiny-random-Llama-3
# Model llamafactory/tiny-random-Llama-3, Size: 8227380 bytes
# Processing model: llava-hf/llava-v1.6-mistral-7b-hf
# Model llava-hf/llava-v1.6-mistral-7b-hf, Size: 15133587296 bytes
# Processing model: lllyasviel/sd-controlnet-canny
# Model lllyasviel/sd-controlnet-canny, Size: 1445254969 bytes
# Processing model: lmsys/vicuna-7b-v1.5
# Model lmsys/vicuna-7b-v1.5, Size: 13476950097 bytes
# Processing model: lucas-leme/FinBERT-PT-BR
# Model lucas-leme/FinBERT-PT-BR, Size: 435772781 bytes
# Processing model: lxyuan/distilbert-base-multilingual-cased-sentiments-student
# Model lxyuan/distilbert-base-multilingual-cased-sentiments-student, Size: 541347048 bytes
# Processing model: madebyollin/sdxl-vae-fp16-fix
# Model madebyollin/sdxl-vae-fp16-fix, Size: 334712113 bytes
# Processing model: madhurjindal/autonlp-Gibberish-Detector-492513457
# Model madhurjindal/autonlp-Gibberish-Detector-492513457, Size: 267866225 bytes
# Processing model: malteos/scincl
# Model malteos/scincl, Size: 439758015 bytes
# Processing model: martin-ha/toxic-comment-model
# Model martin-ha/toxic-comment-model, Size: 267858673 bytes
# Processing model: mattmdjaga/segformer_b2_clothes
# Model mattmdjaga/segformer_b2_clothes, Size: 109582328 bytes
# Processing model: meta-llama/Llama-3.1-8B-Instruct
# Need authorization to retrieve model size from meta-llama/Llama-3.1-8B-Instruct.
# Model meta-llama/Llama-3.1-8B-Instruct, Size: None bytes
# Processing model: michaelfeil/bge-small-en-v1.5
# Model michaelfeil/bge-small-en-v1.5, Size: 133508397 bytes
# Processing model: michellejieli/emotion_text_classifier
# Model michellejieli/emotion_text_classifier, Size: 328537436 bytes
# Processing model: microsoft/resnet-50
# Model microsoft/resnet-50, Size: 102567489 bytes
# Processing model: mistralai/Mistral-7B-Instruct-v0.3
# Need authorization to retrieve model size from mistralai/Mistral-7B-Instruct-v0.3.
# Model mistralai/Mistral-7B-Instruct-v0.3, Size: None bytes
# Processing model: mixedbread-ai/mxbai-embed-large-v1
# Model mixedbread-ai/mxbai-embed-large-v1, Size: 1673132720 bytes
# Processing model: ml6team/keyphrase-extraction-distilbert-inspec
# Model ml6team/keyphrase-extraction-distilbert-inspec, Size: 265503588 bytes
# Processing model: modularai/llama-3.1
# Model modularai/llama-3.1, Size: 64375739808 bytes
# Processing model: mohitsha/tiny-random-testing-bert2gpt2
# Model mohitsha/tiny-random-testing-bert2gpt2, Size: 316738302 bytes
# Processing model: moka-ai/m3e-base
# Model moka-ai/m3e-base, Size: 409141805 bytes
# Processing model: monologg/kobert
# Model monologg/kobert, Size: 368792146 bytes
# Processing model: mpoyraz/wav2vec2-xls-r-300m-cv7-turkish
# Model mpoyraz/wav2vec2-xls-r-300m-cv7-turkish, Size: 1758199977 bytes
# Processing model: mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis
# Model mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis, Size: 328531740 bytes
# Processing model: mtg-upf/discogs-maest-30s-pw-129e
# Model mtg-upf/discogs-maest-30s-pw-129e, Size: 347504246 bytes
# Processing model: myshell-ai/MeloTTS-English
# Model myshell-ai/MeloTTS-English, Size: 207860748 bytes
# Processing model: nateraw/vit-age-classifier
# Model nateraw/vit-age-classifier, Size: 343303671 bytes
# Processing model: naver/splade-cocondenser-selfdistil
# Model naver/splade-cocondenser-selfdistil, Size: 438141995 bytes
# Processing model: ncbi/MedCPT-Query-Encoder
# Model ncbi/MedCPT-Query-Encoder, Size: 437993382 bytes
# Processing model: nesaorg/benchmark_v0
# Model nesaorg/benchmark_v0, Size: 1346372240 bytes
# Processing model: neulab/codebert-java
# Model neulab/codebert-java, Size: 498858859 bytes
# Processing model: neuralmagic/Meta-Llama-3.1-8B-Instruct-FP8
# Model neuralmagic/Meta-Llama-3.1-8B-Instruct-FP8, Size: 9081287016 bytes
# Processing model: neuralmind/bert-base-portuguese-cased
# Model neuralmind/bert-base-portuguese-cased, Size: 438235074 bytes
# Processing model: nferruz/ProtGPT2
# Model nferruz/ProtGPT2, Size: 3134053001 bytes
# Processing model: nfliu/deberta-v3-large_boolq
# Model nfliu/deberta-v3-large_boolq, Size: 1740395824 bytes
# Processing model: nguyenvulebinh/wav2vec2-base-vi
# Model nguyenvulebinh/wav2vec2-base-vi, Size: 380248589 bytes
# Processing model: nlpaueb/legal-bert-base-uncased
# Model nlpaueb/legal-bert-base-uncased, Size: 440474526 bytes
# Processing model: nlpconnect/vit-gpt2-image-captioning
# Model nlpconnect/vit-gpt2-image-captioning, Size: 982141993 bytes
# Processing model: nlptown/bert-base-multilingual-uncased-sentiment
# Model nlptown/bert-base-multilingual-uncased-sentiment, Size: 669491321 bytes
# Processing model: nomic-ai/nomic-embed-text-v1.5
# Model nomic-ai/nomic-embed-text-v1.5, Size: 546938168 bytes
# Processing model: ntu-spml/distilhubert
# Model ntu-spml/distilhubert, Size: 93985618 bytes
# Processing model: numind/NuNER_Zero
# Model numind/NuNER_Zero, Size: 1795685762 bytes
# Processing model: nvidia/speakerverification_en_titanet_large
# Model nvidia/speakerverification_en_titanet_large, Size: 101621760 bytes
# Processing model: obh07/multilingual-e5-base-dolly-15k
# Model obh07/multilingual-e5-base-dolly-15k, Size: 1112197096 bytes
# Processing model: obi/deid_roberta_i2b2
# Model obi/deid_roberta_i2b2, Size: 1417588465 bytes
# Processing model: oliverguhr/fullstop-punctuation-multilang-large
# Model oliverguhr/fullstop-punctuation-multilang-large, Size: 2235559654 bytes
# Processing model: openai/clip-vit-large-patch14
# Model openai/clip-vit-large-patch14, Size: 1710671599 bytes
# Processing model: openai-community/gpt2
# Model openai-community/gpt2, Size: 548118077 bytes
# Processing model: openart-custom/AlbedoBase
# Model openart-custom/AlbedoBase, Size: 6938014070 bytes
# Processing model: openlm-research/open_llama_3b_v2
# Model openlm-research/open_llama_3b_v2, Size: 6853038093 bytes
# Processing model: opensearch-project/opensearch-neural-sparse-encoding-doc-v2-distill
# Model opensearch-project/opensearch-neural-sparse-encoding-doc-v2-distill, Size: 267975343 bytes
# Processing model: optimum-internal-testing/tiny-random-llama
# Model optimum-internal-testing/tiny-random-llama, Size: 4131280 bytes
# Processing model: owkin/phikon
# Model owkin/phikon, Size: 345621802 bytes
# Processing model: padmajabfrl/Gender-Classification
# Model padmajabfrl/Gender-Classification, Size: 267858920 bytes
# Processing model: papluca/xlm-roberta-base-language-detection
# Model papluca/xlm-roberta-base-language-detection, Size: 1112318701 bytes
# Processing model: patrickjohncyh/fashion-clip
# Model patrickjohncyh/fashion-clip, Size: 605239073 bytes
# Processing model: patrickvonplaten/wavlm-libri-clean-100h-base-plus
# Model patrickvonplaten/wavlm-libri-clean-100h-base-plus, Size: 1510890480 bytes
# Processing model: pdelobelle/robbert-v2-dutch-base
# Model pdelobelle/robbert-v2-dutch-base, Size: 467303325 bytes
# Processing model: peft-internal-testing/tiny-dummy-qwen2
# Model peft-internal-testing/tiny-dummy-qwen2, Size: 4872600 bytes
# Processing model: petals-team/StableBeluga2
# Model petals-team/StableBeluga2, Size: 137953382384 bytes
# Processing model: philschmid/bart-large-cnn-samsum
# Model philschmid/bart-large-cnn-samsum, Size: 3251135292 bytes
# Processing model: pierreguillou/ner-bert-base-cased-pt-lenerbr
# Model pierreguillou/ner-bert-base-cased-pt-lenerbr, Size: 433450737 bytes
# Processing model: playgroundai/playground-v2.5-1024px-aesthetic
# Model playgroundai/playground-v2.5-1024px-aesthetic, Size: 20815183532 bytes
# Processing model: pparasurama/raceBERT-ethnicity
# Model pparasurama/raceBERT-ethnicity, Size: 438055497 bytes
# Processing model: prajjwal1/bert-small
# Model prajjwal1/bert-small, Size: 116270890 bytes
# Processing model: princeton-nlp/sup-simcse-roberta-large
# Model princeton-nlp/sup-simcse-roberta-large, Size: 1421571527 bytes
# Processing model: prithivida/parrot_paraphraser_on_T5
# Model prithivida/parrot_paraphraser_on_T5, Size: 891739815 bytes
# Processing model: prs-eth/marigold-normals-lcm-v0-1
# Model prs-eth/marigold-normals-lcm-v0-1, Size: 7740803062 bytes
# Processing model: pyannote/segmentation-3.0
# Need authorization to retrieve model size from pyannote/segmentation-3.0.
# Model pyannote/segmentation-3.0, Size: None bytes
# Processing model: pysentimiento/robertuito-sentiment-analysis
# Model pysentimiento/robertuito-sentiment-analysis, Size: 435237284 bytes
# Processing model: qanastek/51-languages-classifier
# Model qanastek/51-languages-classifier, Size: 1112406172 bytes
# Processing model: reazon-research/reazonspeech-nemo-v2
# Model reazon-research/reazonspeech-nemo-v2, Size: 2477946880 bytes
# Processing model: rinna/japanese-cloob-vit-b-16
# Model rinna/japanese-cloob-vit-b-16, Size: 786618277 bytes
# Processing model: rizvandwiki/gender-classification
# Model rizvandwiki/gender-classification, Size: 343264177 bytes
# Processing model: s-nlp/roberta_toxicity_classifier
# Model s-nlp/roberta_toxicity_classifier, Size: 501037970 bytes
# Processing model: salmanshahid/vad
# No model files found for salmanshahid/vad
# Model salmanshahid/vad, Size: None bytes
# Processing model: sanchit-gandhi/whisper-medium-fleurs-lang-id
# Model sanchit-gandhi/whisper-medium-fleurs-lang-id, Size: 615063224 bytes
# Processing model: seara/rubert-tiny2-russian-sentiment
# Model seara/rubert-tiny2-russian-sentiment, Size: 116813471 bytes
# Processing model: sentence-transformers/all-mpnet-base-v2
# Model sentence-transformers/all-mpnet-base-v2, Size: 983570429 bytes
# Processing model: sentence-transformers-testing/stsb-bert-tiny-safetensors
# Model sentence-transformers-testing/stsb-bert-tiny-safetensors, Size: 17556771 bytes
# Processing model: sentinet/suicidality
# Model sentinet/suicidality, Size: 438004081 bytes
# Processing model: shahrukhx01/bert-mini-finetune-question-detection
# Model shahrukhx01/bert-mini-finetune-question-detection, Size: 44719369 bytes
# Processing model: shi-labs/oneformer_coco_swin_large
# Model shi-labs/oneformer_coco_swin_large, Size: 879397581 bytes
# Processing model: shibing624/text2vec-base-chinese
# Model shibing624/text2vec-base-chinese, Size: 815866513 bytes
# Processing model: smallcloudai/Refact-1_6B-fim
# Model smallcloudai/Refact-1_6B-fim, Size: 3171755929 bytes
# Processing model: solidrust/Codestral-22B-v0.1-hf-AWQ
# Model solidrust/Codestral-22B-v0.1-hf-AWQ, Size: 12155448872 bytes
# Processing model: sonoisa/sentence-bert-base-ja-mean-tokens-v2
# Model sonoisa/sentence-bert-base-ja-mean-tokens-v2, Size: 442550705 bytes
# Processing model: speechbrain/spkrec-ecapa-voxceleb
# Model speechbrain/spkrec-ecapa-voxceleb, Size: 88852935 bytes
# Processing model: sshleifer/distilbart-cnn-12-6
# Model sshleifer/distilbart-cnn-12-6, Size: 1222317369 bytes
# Processing model: stabilityai/stable-diffusion-xl-base-1.0
# Model stabilityai/stable-diffusion-xl-base-1.0, Size: 13875355636 bytes
# Processing model: stable-diffusion-v1-5/stable-diffusion-inpainting
# Model stable-diffusion-v1-5/stable-diffusion-inpainting, Size: 8222539660 bytes
# Processing model: stablediffusionapi/realistic-vision-51
# Model stablediffusionapi/realistic-vision-51, Size: 5481452116 bytes
# Processing model: stepfun-ai/GOT-OCR2_0
# Model stepfun-ai/GOT-OCR2_0, Size: 1432121416 bytes
# Processing model: tasksource/deberta-small-long-nli
# Model tasksource/deberta-small-long-nli, Size: 567625522 bytes
# Processing model: tencent/DepthCrafter
# Model tencent/DepthCrafter, Size: 3049435868 bytes
# Processing model: textattack/bert-base-uncased-snli
# Model textattack/bert-base-uncased-snli, Size: 437986855 bytes
# Processing model: theainerd/Wav2Vec2-large-xlsr-hindi
# Model theainerd/Wav2Vec2-large-xlsr-hindi, Size: 1262196247 bytes
# Processing model: thenlper/gte-large
# Model thenlper/gte-large, Size: 2343473903 bytes
# Processing model: tiiuae/falcon-7b-instruct
# Model tiiuae/falcon-7b-instruct, Size: 42128333052 bytes
# Processing model: timbrooks/instruct-pix2pix
# Model timbrooks/instruct-pix2pix, Size: 8222543344 bytes
# Processing model: timm/resnet50.a1_in1k
# Model timm/resnet50.a1_in1k, Size: 102545229 bytes
# Processing model: timpal0l/mdeberta-v3-base-squad2
# Model timpal0l/mdeberta-v3-base-squad2, Size: 1112951793 bytes
# Processing model: tner/roberta-large-ontonotes5
# Model tner/roberta-large-ontonotes5, Size: 1417562865 bytes
# Processing model: to-be/donut-base-finetuned-invoices
# Model to-be/donut-base-finetuned-invoices, Size: 809253243 bytes
# Processing model: tohoku-nlp/bert-base-japanese
# Model tohoku-nlp/bert-base-japanese, Size: 445021143 bytes
# Processing model: trl-internal-testing/tiny-random-LlamaForCausalLM
# Model trl-internal-testing/tiny-random-LlamaForCausalLM, Size: 4136310 bytes
# Processing model: trpakov/vit-face-expression
# Model trpakov/vit-face-expression, Size: 343282353 bytes
# Processing model: tsmatz/xlm-roberta-ner-japanese
# Model tsmatz/xlm-roberta-ner-japanese, Size: 1109914336 bytes
# Processing model: tuner007/pegasus_paraphrase
# Model tuner007/pegasus_paraphrase, Size: 2275437102 bytes
# Processing model: ufal/robeczech-base
# Model ufal/robeczech-base, Size: 504184434 bytes
# Processing model: unitary/toxic-bert
# Model unitary/toxic-bert, Size: 438033929 bytes
# Processing model: unsloth/llama-3-8b-bnb-4bit
# Model unsloth/llama-3-8b-bnb-4bit, Size: 5702746405 bytes
# Processing model: unslothai/1
# Model unslothai/1, Size: 176 bytes
# Processing model: vectara/hallucination_evaluation_model
# Model vectara/hallucination_evaluation_model, Size: 438535352 bytes
# Processing model: vikhyatk/moondream2
# Model vikhyatk/moondream2, Size: 3736040266 bytes
# Processing model: vikp/surya_det3
# Model vikp/surya_det3, Size: 5112 bytes
# Processing model: vinai/phobert-base-v2
# Model vinai/phobert-base-v2, Size: 540322347 bytes
# Processing model: vinid/plip
# Model vinid/plip, Size: 605241933 bytes
# Processing model: w11wo/indonesian-roberta-base-posp-tagger
# Model w11wo/indonesian-roberta-base-posp-tagger, Size: 496386793 bytes
# Processing model: wangqixun/YamerMIX_v8
# Model wangqixun/YamerMIX_v8, Size: 6938012846 bytes
# Processing model: wasmdashai/wasmai-7b-v1
# Model wasmdashai/wasmai-7b-v1, Size: 30462504632 bytes
# Processing model: xiaxy/elastic-bert-chinese-ner
# Model xiaxy/elastic-bert-chinese-ner, Size: 406819313 bytes
# Processing model: xlnet/xlnet-base-cased
# Model xlnet/xlnet-base-cased, Size: 467042463 bytes
# Processing model: yangheng/deberta-v3-base-absa-v1.1
# Model yangheng/deberta-v3-base-absa-v1.1, Size: 737785771 bytes
# Processing model: ybelkada/tiny-random-T5ForConditionalGeneration-calibrated
# Model ybelkada/tiny-random-T5ForConditionalGeneration-calibrated, Size: 4488837 bytes
# Processing model: yikuan8/Clinical-Longformer
# Model yikuan8/Clinical-Longformer, Size: 594988059 bytes
# Processing model: yiyanghkust/finbert-tone
# Model yiyanghkust/finbert-tone, Size: 439101405 bytes
# Processing model: yosuke/bert-base-japanese-char
# Model yosuke/bert-base-japanese-char, Size: 243201356 bytes
# Processing model: zer0int/CLIP-GmP-ViT-L-14
# Model zer0int/CLIP-GmP-ViT-L-14, Size: 6408972496 bytes
# Processed 363 models. Results saved to 'HF_topmodels.csv'.
