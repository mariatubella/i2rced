# %%
import pandas as pd
df = pd.read_csv('GHlocation_vectara_members.csv_complete.csv')
df.columns
# Out:
# Index(['username', 'name', 'role', 'has_github', 'location', 'gender'], dtype='object')

# %%
import os
folder = '/home/maria/Escriptori/I2RCED/i2rced/organisations/complete_organisations'
for file_name in os.listdir(folder):
        if file_name.endswith('.csv'):  # Process only CSV files
            file_path = os.path.join(folder, file_name)

            # Read the CSV file
            df = pd.read_csv(file_path)
            df['gender'] = df['gender'].str.replace('\n', '').str.lower()
            df.to_csv(file_path, index=False)

# %%
df = pd.read_csv('GHlocation_vectara_members.csv_complete.csv')
df
# Out:
#            username                 name  role  has_github           location  \
# 0          ofermend    Ofer Mendelevitch  user        True             SF Bay
# 1         awadallah        Amr Awadallah  user        True      Palo Alto, CA
# 2          amin3141           Amin Ahmad  user       False                NaN
# 3      viveksourabh        Vivek Sourabh  user       False                NaN
# 4          eskibars       Shane Connelly  user       False                NaN
# 5       clefourrier  Clémentine Fourrier  user        True             France
# 6          int64max     Tallat M Shafaat  user       False                NaN
# 7        wadalawala    Mansur Wadalawala  user       False                NaN
# 8            sulekz         Suleman Kazi  user       False                NaN
# 9        Miaoran000           Miaoran Li  user       False                NaN
# 10  forrest-vectara    Forrest Sheng Bao  user       False                NaN
# 11          nthakur        Nandan Thakur  user        True  Waterloo, Ontario
# 12    adeel-vectara          Adeel Ehsan  user        True                NaN
# 13            pwozz             Paul Woz  user       False                NaN
# 14          mrderyk       Deryk DeGuzman  user        True                NaN
# 15      justinsight         Justin Hayes  user       False                NaN
# 16    david-oplatka        David Oplatka  user        True          Palo Alto
# 17    david-vectara                David  user       False                NaN
# 18      Nidal4GenAI         Nidal Zoghbi  user       False                NaN
# 19           nkwbtb               Rogger  user       False                NaN
# 20       toastedqu2             Renyi Qu  user        True                NaN
# 21        cjvectara                   CJ  user       False                NaN
# 22        aamirbutt           Aamir Butt  user        True          Islamabad
# 23        Joemlee78           Joseph Lee  user       False                NaN
# 24         Ammarfay        Ammar Fayoumi  user       False                NaN
# 25      Bayparkbear        Steffan J Mos  user       False                NaN
#
#      gender
# 0      male
# 1      male
# 2      male
# 3      male
# 4      male
# 5    female
# 6      male
# 7      male
# 8   unknown
# 9   unknown
# 10     male
# 11     male
# 12     male
# 13     male
# 14     male
# 15     male
# 16     male
# 17     male
# 18     male
# 19  unknown
# 20  unknown
# 21  unknown
# 22     male
# 23  unknown
# 24     male
# 25     male
